# %%
import pandas as pd
csv_res=pd.read_csv('/home/karim-tito/stat_reliability_measure/logs/linear_gaussian_tests/aggr_res.csv')
p_t=1e-15
select_p_t=csv_res['p_t']==p_t
csv_sel=csv_res[select_p_t]
csv_sel[['method','rho','n_rep','N','T','mean abs error','mean est','std est','min_rate','mean_calls','mean time','d_t_decay','alpha','g_target','v_min_opt',"adapt_d_t"]].tail(10)
# Out:
#                             method  rho  n_rep    N  T  mean abs error  \
# 307  langevin_adapt_pyt_unadjusted  NaN     20  100  5    2.785474e-16
# 308  langevin_adapt_pyt_unadjusted  NaN     20  100  3    4.462149e-16
# 309  langevin_adapt_pyt_unadjusted  NaN     20  100  5    4.081667e-16
# 310  langevin_adapt_pyt_unadjusted  NaN     20  100  5    3.987234e-16
# 311  langevin_adapt_pyt_unadjusted  NaN     20  100  5    2.855826e-16
# 312  langevin_adapt_pyt_unadjusted  NaN     20  100  5    3.391969e-16
# 313  langevin_adapt_pyt_unadjusted  NaN     20  100  5    3.497838e-16
# 314  langevin_adapt_pyt_unadjusted  NaN     20  100  5    3.449560e-16
# 315  langevin_adapt_pyt_unadjusted  NaN     20  100  5    3.112364e-16
# 316  langevin_adapt_pyt_unadjusted  NaN     20  100  5    2.879526e-16
#
#          mean est       std est  min_rate  mean_calls  mean time  d_t_decay  \
# 307  7.254590e-16  1.435452e-16      0.90    408895.0   3.875643      0.995
# ...

# %%
csv_sel.sort_values(by='mean abs error').head(15
                        )[['method','N','T','n_rep','mean abs error','mean_calls','std_calls','mean time','alpha','g_target','adapt_d_t','v_min_opt','target_accept','min_rate','d_t_decay','accept_spread']]
# Out:
#                             method     N   T  n_rep  mean abs error  \
# 303                       amls_pyt  1000   1     20    1.460812e-16
# 18                        amls_pyt  1000   1    100    2.201542e-16
# 304                       amls_pyt  1000   5     20    2.335679e-16
# 206   langevin_base_pyt_unadjusted  1000  10    100    2.676932e-16
# 40   langevin_adapt_pyt_unadjusted   100   5     10    2.739756e-16
# 39   langevin_adapt_pyt_unadjusted   100   5     10    2.739756e-16
# 307  langevin_adapt_pyt_unadjusted   100   5     20    2.785474e-16
# 272   langevin_base_pyt_unadjusted  1000  10     10    2.808125e-16
# 17                        amls_pyt   500   1    100    2.850332e-16
# 203   langevin_base_pyt_unadjusted  1000  10    100    2.854503e-16
# 311  langevin_adapt_pyt_unadjusted   100   5     20    2.855826e-16
# 298  langevin_adapt_pyt_unadjusted   100   5     20    2.870725e-16
# 316  langevin_adapt_pyt_unadjusted   100   5     20    2.879526e-16
# ...

# %%
import pandas as pd
csv_res=pd.read_csv('/home/karim-tito/stat_reliability_measure/logs/linear_gaussian_tests/aggr_res.csv')
p_t=1e-10
select_p_t=csv_res['p_t']==p_t
csv_sel=csv_res[select_p_t]
csv_sel[['method','rho','n_rep','N','T','mean abs error','mean est','std est','min_rate','mean_calls','mean time','d_t_decay','alpha','g_target','v_min_opt',"adapt_d_t"]].tail(10)
# Out:
#                             method  rho  n_rep    N   T  mean abs error  \
# 234   langevin_base_pyt_unadjusted  1.0     50  100   1    1.399635e-09
# 235   langevin_base_pyt_unadjusted  1.0     50  100   1    9.103400e-11
# 236   langevin_base_pyt_unadjusted  1.0     50   10   5    1.446720e-10
# 237   langevin_base_pyt_unadjusted  1.0     50  100   5    8.791212e-11
# 238   langevin_base_pyt_unadjusted  1.0     50  100   5    7.973652e-11
# 239   langevin_base_pyt_unadjusted  1.0     50   10  10    2.187158e-10
# 240   langevin_base_pyt_unadjusted  1.0     50  100  10    4.666425e-11
# 241   langevin_base_pyt_unadjusted  1.0     50  100   1    9.558196e-11
# 242   langevin_base_pyt_unadjusted  1.0     50  100   5    7.673865e-11
# 317  langevin_adapt_pyt_unadjusted  NaN     20  100   5    2.958144e-11
#
#          mean est       std est  min_rate  mean_calls  mean time  d_t_decay  \
# 234  1.318954e-09  9.169861e-09       0.4         NaN   0.574169      0.999
# ...

# %%
csv_sel.sort_values(by='mean abs error').head(15
                        )[['method','N','T','n_rep','mean abs error','mean_calls','std_calls','mean time','alpha','g_target','adapt_d_t','v_min_opt','target_accept','min_rate','d_t_decay','accept_spread']]
# Out:
#                             method    N   T  n_rep  mean abs error  \
# 317  langevin_adapt_pyt_unadjusted  100   5     20    2.958144e-11
# 21    langevin_base_pyt_unadjusted  100   5     10    3.390278e-11
# 10                        amls_pyt   40   1     10    4.164495e-11
# 11                        amls_pyt   40   1     10    4.584897e-11
# 240   langevin_base_pyt_unadjusted  100  10     50    4.666425e-11
# 0                         amls_pyt   40   1     10    5.362830e-11
# 12                        amls_pyt   40   1     10    7.283287e-11
# 242   langevin_base_pyt_unadjusted  100   5     50    7.673865e-11
# 238   langevin_base_pyt_unadjusted  100   5     50    7.973652e-11
# 237   langevin_base_pyt_unadjusted  100   5     50    8.791212e-11
# 235   langevin_base_pyt_unadjusted  100   1     50    9.103400e-11
# 227   langevin_base_pyt_unadjusted  100   1     10    9.438453e-11
# 241   langevin_base_pyt_unadjusted  100   1     50    9.558196e-11
# ...
