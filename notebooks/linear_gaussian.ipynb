# %%
import pandas as pd

# %%
csv_res=pd.read_csv('/home/karim-tito/stat_reliability_measure/logs/linear_gaussian_tests/aggr_res.csv')
p_t=1e-10 
select_p_t=csv_res['p_t']==p_t
csv_sel=csv_res[select_p_t]
csv_sel[['method','rho','n_rep','N','T','mean abs error','mean est','min_rate','mean time','K','s','batch_opt','alpha']]

# %%
# Out:
#                            method   rho  n_rep    N   T  mean abs error  \
# 0                        amls_pyt   NaN     10   40   1    5.362830e-11
# 10                       amls_pyt   NaN     10   40   1    4.164495e-11
# 11                       amls_pyt   NaN     10   40   1    4.584897e-11
# 12                       amls_pyt   NaN     10   40   1    7.283287e-11
# 21   langevin_base_pyt_unadjusted  1.00     10  100   5    3.390278e-11
# 225  langevin_base_pyt_unadjusted  1.00     10  100   1    2.750282e-10
# 226  langevin_base_pyt_unadjusted  1.50     10  100   1    9.977378e-11
# 227  langevin_base_pyt_unadjusted  1.15     10  100   1    9.438453e-11
# 228  langevin_base_pyt_unadjusted  1.15     10   40   1    9.831770e-11
# 229  langevin_base_pyt_unadjusted  1.15     50   40   1    9.710543e-11
# 230  langevin_base_pyt_unadjusted  1.10     50   40   1    9.598892e-11
# 231  langevin_base_pyt_unadjusted  1.10     50   40   1    1.080765e-10
# 232  langevin_base_pyt_unadjusted  1.10     50  100   1    1.032977e-10
# 233  langevin_base_pyt_unadjusted  1.00     50   10   1    9.803733e-11
# 234  langevin_base_pyt_unadjusted  1.00     50  100   1    1.399635e-09
# 235  langevin_base_pyt_unadjusted  1.00     50  100   1    9.103400e-11
# 236  langevin_base_pyt_unadjusted  1.00     50   10   5    1.446720e-10
# 237  langevin_base_pyt_unadjusted  1.00     50  100   5    8.791212e-11
# 238  langevin_base_pyt_unadjusted  1.00     50  100   5    7.973652e-11
# 239  langevin_base_pyt_unadjusted  1.00     50   10  10    2.187158e-10
# 240  langevin_base_pyt_unadjusted  1.00     50  100  10    4.666425e-11
# 241  langevin_base_pyt_unadjusted  1.00     50  100   1    9.558196e-11
# 242  langevin_base_pyt_unadjusted  1.00     50  100   5    7.673865e-11
#
#          mean est  min_rate  mean time     K    s batch_opt  alpha
# 0    8.267559e-11       0.4   1.964887  24.0  1.0     False    NaN
# 10   7.363855e-11       0.4   0.325445  24.0  1.0      True    NaN
# 11   9.426599e-11       0.4   0.380521  24.0  1.0      True    NaN
# 12   1.002945e-10       0.4   0.334783  24.0  1.0      True    NaN
# 21   7.215446e-11       0.9   1.794961   NaN  NaN       NaN  0.010
# 225  2.082031e-10       0.4   0.344282   NaN  NaN       NaN  0.010
# 226  2.262180e-13       0.4   0.276346   NaN  NaN       NaN  0.010
# 227  5.615469e-12       0.4   0.309462   NaN  NaN       NaN  0.010
# 228  2.008792e-11       0.4   0.235089   NaN  NaN       NaN  0.010
# 229  7.615808e-12       0.4   0.228940   NaN  NaN       NaN  0.010
# 230  1.574907e-11       0.4   0.240550   NaN  NaN       NaN  0.010
# 231  3.325840e-11       0.4   0.397487   NaN  NaN       NaN  0.005
# 232  2.364202e-11       0.4   0.555195   NaN  NaN       NaN  0.005
# 233  1.962674e-12       0.4   0.343884   NaN  NaN       NaN  0.005
# 234  1.318954e-09       0.4   0.574169   NaN  NaN       NaN  0.005
# 235  9.535619e-12       0.4   0.588059   NaN  NaN       NaN  0.005
# 236  1.515900e-10       0.4   0.869475   NaN  NaN       NaN  0.005
# 237  1.340276e-10       0.4   1.824931   NaN  NaN       NaN  0.005
# 238  1.328122e-10       0.4   1.818384   NaN  NaN       NaN  0.005
# 239  2.848293e-10       0.4   1.528968   NaN  NaN       NaN  0.005
# 240  1.248727e-10       0.4   3.462166   NaN  NaN       NaN  0.005
# 241  9.746407e-12       0.4   0.571346   NaN  NaN       NaN  0.005
# 242  1.154738e-10       0.4   1.918221   NaN  NaN       NaN  0.005

# %%
csv_res.columns
# Out:
# Index(['p_t', 'method', 'N', 'rho', 'n_rep', 'T', 'alpha', 'min_rate',
#        'mean time', 'std time', 'mean est', 'bias', 'mean abs error',
#        'mean rel error', 'std est', 'freq underest', 'gpu_name', 'cpu_name',
#        'gaussian_latent', 'ratio', 'K', 's', 'cores_number', 'batch_opt',
#        'mean_calls', 'std_calls', 'd', 'kernel', 'adapt_t', 'adapt_d_t_mcmc',
#        'adapt_d_t', 'd_t_decay', 'd_t_gain', 'target_accept', 'accept_spread',
#        'g_target'],
#       dtype='object')

# %%
csv_res['p_t']
# Out:
# 0      1.000000e-10
# 1      1.000000e-05
# 2      1.000000e-05
# 3      1.000000e-05
# 4      1.000000e-05
#            ...
# 220    1.000000e-15
# 221    1.000000e-15
# 222    1.000000e-15
# 223    1.000000e-15
# 224    1.000000e-15
# Name: p_t, Length: 225, dtype: float64
