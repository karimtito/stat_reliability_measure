# %% [markdown]
# ## Importing libraries

# %%
import numpy as np 
import numpy.linalg as LA
import scipy.stats as stat
from time import time
import os

from scipy.special import betainc
import tensorflow as tf
physical_devices=tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(device=physical_devices[0],enable=True)
import tensorflow_datasets as tfds
from tensorflow_probability import distributions as tfd

# %%
import foolbox as fb

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import langevin_smc as smc
import sampling_tools as s_t
from utils import normal_kernel
from importlib import reload
reload(smc)
reload(s_t)
# Out:
# <module 'sampling_tools' from '/home/karim-tito/sampling-reliability-measure/karimtito_reliability_meassure/sampling_tools.py'>

# %% [markdown]
# # Neural Network Model tests for vanilla Langevin SMC-based reliability measure

# %% [markdown]
# ## 1. Toy model on MNIST

# %% [markdown]
# Let $f$ be neural network model and $x_0$ be an input of class index $c$, correctly classified by $f$.
# We want to estimate the local failure probability $p$, defined by,
# $$p=\mathbb{P}[h(x_0+X)\geq 0]$$
# where $h:x\mapsto \max_{j\neq c}f_j(x)-f_c(x)$ and $X\sim \mathcal{U}([-\varepsilon,\varepsilon]^d)$ under measure $\mathbb{P}$.
# We are interested in the case where $p$ is especially small (say $<10^{-10}$).
# We define the potential function $V$,
# $$V:x\mapsto (f_c(x_0+x)-\max_{j\neq c}f_j(x_0+x))_+$$
# So that $p=\mathbb{P}[V(X)=0]$. For $\beta \in \R_+ \cup \{+\infty\}$, we denote $\mu_{\beta}$ the probability measure on $[-\varepsilon,\varepsilon]^d$ proportional to $e^{-\beta V(x)}dx$ and we denote $Z_{\beta}$ it's normalization constant. Then, one can notice that,
# $$Z_{\infty} = \int_{[-\varepsilon,\varepsilon]^d} \mathbb{1}_{V(x)=0}dx=p

# %% [markdown]
# ## 2. Loading and pre-processing MNIST data

# %%
nb_classes=10
ds_train, ds_val, ds_test = tfds.load('mnist',split=('train[:95%]','train[95%:]','test'),as_supervised=True)

def label_to_one_hot(data, label):
    return data, tf.one_hot(label,nb_classes,on_value=1.0,off_value=0.0)
batch_size=64
ds_train=ds_train.map(lambda data,label: (data/255,label)).map(label_to_one_hot).batch(batch_size)
ds_val=ds_val.map(lambda data,label: (data/255,label)).map(label_to_one_hot).batch(batch_size)
ds_test=ds_test.map(lambda data,label: (data/255,label)).map(label_to_one_hot).batch(batch_size)

# %% [markdown]
# ## 3. Creating DNN toy models

# %%
nets_dir= "/home/karim-tito/sampling-reliability-measure/karimtito_reliability_meassure/models/mnist"
net_paths=[]

# %%
net_path=os.path.join(nets_dir,'dnn')
net_paths.append(net_path)
dnn = tf.keras.Sequential()
dnn.add(tf.keras.layers.Flatten())
dnn.add(tf.keras.layers.Dense(100,activation='relu'))
dnn.add(tf.keras.layers.Dense(100,activation ='relu'))
dnn.add(tf.keras.layers.Dense(100,activation='relu'))
dnn.add(tf.keras.layers.Dense(10))

model_dnn_2 = tf.keras.Sequential()
model_dnn_2.add(tf.keras.layers.Flatten())
model_dnn_2.add( tf.keras.layers.Dense(200,'relu'))
model_dnn_2.add(tf.keras.layers.Dense(10,))

# %%
model_dnn_4 = tf.keras.Sequential()
model_dnn_4.add(tf.keras.layers.Flatten())
model_dnn_4.add( tf.keras.layers.Dense(200,'relu'))
model_dnn_4.add(
                            tf.keras.layers.Dense(100,'relu'))
model_dnn_4.add(    tf.keras.layers.Dense(100,'relu'))
model_dnn_4.add(        tf.keras.layers.Dense(10))

x = tf.keras.Input(shape = (28,28,1))
output = tf.keras.layers.Conv2D(filters=32,kernel_size=3,padding='same',activation='relu')(x)
output = tf.keras.layers.Conv2D(filters=32,kernel_size=3,padding='same',activation='relu',strides=2)(output)
output=tf.keras.layers.Conv2D(filters=64,kernel_size=3, padding='same',
activation='relu')(output)
output=tf.keras.layers.Conv2D(filters=64,kernel_size=3, padding='same',strides=2,
activation='relu')(output)
output = tf.keras.layers.Flatten()(output)
output = tf.keras.layers.Dense(units=100,activation='relu')(output)
output = tf.keras.layers.Dense(units=10)(output)
model_cnn= tf.keras.Model(inputs=x, outputs=output)
model_cnn.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-2),loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),metrics='accuracy')

# %% [markdown]
# ## 4. Training the DNNs

# %%
model_dnn_2.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-1),
loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),metrics='accuracy')
model_dnn_2.fit(ds_train,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 891/891 [==============================] - 2s 2ms/step - loss: 0.3747 - accuracy: 0.8966
# Epoch 2/10
# 891/891 [==============================] - 1s 1ms/step - loss: 0.1958 - accuracy: 0.9444
# Epoch 3/10
# 891/891 [==============================] - 1s 1ms/step - loss: 0.1467 - accuracy: 0.9585
# Epoch 4/10
# 891/891 [==============================] - 1s 1ms/step - loss: 0.1181 - accuracy: 0.9670
# Epoch 5/10
# 891/891 [==============================] - 1s 2ms/step - loss: 0.0989 - accuracy: 0.9732
# Epoch 6/10
# 891/891 [==============================] - 1s 2ms/step - loss: 0.0849 - accuracy: 0.9770
# Epoch 7/10
# 891/891 [==============================] - 1s 1ms/step - loss: 0.0741 - accuracy: 0.9800
# Epoch 8/10
# 891/891 [==============================] - 1s 1ms/step - loss: 0.0655 - accuracy: 0.9822
# Epoch 9/10
# 891/891 [==============================] - 1s 1ms/step - loss: 0.0584 - accuracy: 0.9841
# Epoch 10/10
# 891/891 [==============================] - 1s 1ms/step - loss: 0.0524 - accuracy: 0.9860

# %%
nets_dir =  '/home/karim-tito/sampling-reliability-measure/karimtito_reliability_meassure/models/mnist'

# %%
model_dnn_2.evaluate(ds_test)

tf.keras.models.save_model(model=model_dnn_2,filepath=os.path.join(nets_dir,"dnn_2.h5"),save_format='h5')
# Out:
# 157/157 [==============================] - 1s 2ms/step - loss: 0.0747 - accuracy: 0.9760

# %%
model_cnn.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-1),
loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),metrics='accuracy')
model_cnn.fit(ds_train,epochs=4,verbose=1)
model_cnn.evaluate(ds_test)
tf.keras.models.save_model(model=model_cnn,filepath=os.path.join(nets_dir,"cnn.h5"),save_format='h5')
# Out:
# Epoch 1/4
# 891/891 [==============================] - 3s 3ms/step - loss: 0.0222 - accuracy: 0.9935
# Epoch 2/4
# 891/891 [==============================] - 3s 3ms/step - loss: 0.0174 - accuracy: 0.9945
# Epoch 3/4
# 891/891 [==============================] - 3s 3ms/step - loss: 0.0157 - accuracy: 0.9941
# Epoch 4/4
# 891/891 [==============================] - 3s 3ms/step - loss: 0.0132 - accuracy: 0.9959
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9882

# %%
model_dnn_4.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-3),
loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),metrics='accuracy')
model_dnn_4.fit(ds_train,epochs=8,verbose=1)
model_dnn_4.evaluate(ds_test)
tf.keras.models.save_model(model=model_dnn_4,filepath=os.path.join(nets_dir,"dnn_4.h5"),save_format='h5')
# Out:
# Epoch 1/8
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0170 - accuracy: 0.9956
# Epoch 2/8
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0165 - accuracy: 0.9955
# Epoch 3/8
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0129 - accuracy: 0.9965
# Epoch 4/8
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0141 - accuracy: 0.9961
# Epoch 5/8
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0130 - accuracy: 0.9959
# Epoch 6/8
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0133 - accuracy: 0.9964
# Epoch 7/8
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0138 - accuracy: 0.9959
# Epoch 8/8
# 891/891 [==============================] - 3s 3ms/step - loss: 0.0138 - accuracy: 0.9965
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1374 - accuracy: 0.9826

# %%
model_dnn_4.evaluate(ds_test)
# Out:
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1374 - accuracy: 0.9826
# [0.13741649687290192, 0.9825999736785889]

# %%
dnn.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-2),
loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),metrics='accuracy')
dnn.fit(ds_train,epochs=15,verbose=1)
dnn.evaluate(ds_test)
# Out:
# Epoch 1/15
# 891/891 [==============================] - 3s 3ms/step - loss: 0.0520 - accuracy: 0.9853
# Epoch 2/15
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0500 - accuracy: 0.9862
# Epoch 3/15
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0480 - accuracy: 0.9864
# Epoch 4/15
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0461 - accuracy: 0.9870
# Epoch 5/15
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0443 - accuracy: 0.9875
# Epoch 6/15
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0426 - accuracy: 0.9881
# Epoch 7/15
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0409 - accuracy: 0.9890
# Epoch 8/15
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0393 - accuracy: 0.9895
# Epoch 9/15
# 891/891 [==============================] - 2s 3ms/step - loss: 0.0377 - accuracy: 0.9899
# Epoch 10/15
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0362 - accuracy: 0.9907
# Epoch 11/15
# 891/891 [==============================] - 2s 3ms/step - loss: 0.0348 - accuracy: 0.9912
# Epoch 12/15
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0334 - accuracy: 0.9917
# Epoch 13/15
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0321 - accuracy: 0.9924
# Epoch 14/15
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0308 - accuracy: 0.9930
# Epoch 15/15
# 891/891 [==============================] - 2s 2ms/step - loss: 0.0296 - accuracy: 0.9936
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0841 - accuracy: 0.9761
# [0.08408880233764648, 0.9761000275611877]

# %%
tf.keras.models.save_model(model=dnn,filepath=os.path.join(nets_dir,"dnn.h5"),save_format='h5')

# %% [markdown]
# ## (3+4)#. Loading the DNNs

# %%
nets_dir =  '/home/karim-tito/sampling-reliability-measure/karimtito_reliability_meassure/models/mnist'
model_dnn_2 = tf.keras.models.load_model(filepath=os.path.join(nets_dir,"dnn_2.h5"))
model_dnn_4 = tf.keras.models.load_model(filepath=os.path.join(nets_dir,"dnn_4.h5"))
dnn= tf.keras.models.load_model(filepath=os.path.join(nets_dir,"dnn.h5"))
model_cnn = tf.keras.models.load_model(filepath=os.path.join(nets_dir,"cnn.h5"))

# %%
models=[model_dnn_2, dnn,model_dnn_4, model_cnn]
model_names=['dnn_2','dnn_3','dnn_4','cnn']

# %% [markdown]
# ## 5. Instancing potential and potential gradient functions

# %%
l=40
test_model= model_cnn
for X,y in ds_test.take(1):
    logits = test_model(X)
    y_true= tf.argmax(y,-1)

y_pred= tf.argmax(logits,-1)
correct_idx=y_pred==y_true

x_0,y_0 = X[correct_idx][l], tf.cast(y_true[correct_idx][l],tf.int32)
X_correct, label_correct= X[correct_idx], tf.cast(y_true[correct_idx],tf.int32)

# %%
normal_dist=tfd.Normal(loc=0,scale=1)

def V(x_,x_0,model,target_class,epsilon=0.05,gaussian_latent_var=True,clipping=True, clip_min=0, clip_max=1,reshape=True,input_shape=(28,28,1)):
    if gaussian_latent_var:
        u=epsilon*(2*normal_dist.cdf(x_)-1)
    else:
        u=x_
    if reshape:
        u=tf.reshape(u,(u.shape[0],)+input_shape)
    x_p = x_0+u if not clipping else tf.clip_by_value(x_0+u,clip_value_min=clip_min,clip_value_max=clip_max)
    v = smc.compute_V_tf(model=model,input=x_p,target_class=target_class)
    return v

def gradV(x_,x_0,model,target_class,epsilon=0.05,gaussian_latent_var=True,clipping=True, clip_min=0, clip_max=1,reshape=True,input_shape=(28,28,1)):
    if gaussian_latent_var:
        u=epsilon*(2*normal_dist.cdf(x_)-1)
    else:
        u=x_
    if reshape:
        u=tf.reshape(u,(u.shape[0],)+input_shape)
    x_p = x_0+u if not clipping else tf.clip_by_value(x_0+u,clip_value_min=clip_min,clip_value_max=clip_max)
    _,grad_u = smc.compute_V_grad_tf(model=model,input=x_p,target_class=target_class)
    grad_u=tf.reshape(grad_u,x_.shape)
    if gaussian_latent_var:
        #TODO
        grad_x=normal_dist.prob(x_)*grad_u/(2*epsilon)
    else:
        grad_x=grad_u
    return grad_x

# %%
epsilon=0.0001
x_ =tf.random.normal((100,784))
v=V(x_=x_,x_0=x_0,model=test_model,target_class=y_0,epsilon=epsilon)
lr=5
grad_v=gradV(x_=x_,x_0=x_0,model=test_model,target_class=y_0,epsilon=epsilon)
x__=tf.clip_by_value(x_-lr*grad_v,clip_value_min=0,clip_value_max=1)
v_=V(x_=x__,x_0=x_0,model=test_model,target_class=y_0,epsilon=epsilon)
v_-v
# Out:
# <tf.Tensor: shape=(100,), dtype=float32, numpy=
# array([-0.01006413, -0.01109028, -0.01189899, -0.01058006, -0.01024437,
#        -0.00877285, -0.01077366, -0.00924873, -0.01157188, -0.01019382,
#        -0.0111742 , -0.01180172, -0.00935078, -0.01048946, -0.01026821,
#        -0.01064396, -0.01058769, -0.01050854, -0.01135159, -0.01064968,
#        -0.01039219, -0.01129913, -0.01077652, -0.01064968, -0.01046658,
#        -0.01055241, -0.01133442, -0.0100565 , -0.01137257, -0.00903034,
#        -0.01144981, -0.01171589, -0.00998592, -0.00992298, -0.0102663 ,
#        -0.01238537, -0.01023102, -0.01086044, -0.01083565, -0.01243877,
#        -0.0119915 , -0.00958824, -0.00874138, -0.00977802, -0.01079655,
#        -0.01029301, -0.00942802, -0.01088905, -0.01074028, -0.01154327,
#        -0.01153278, -0.01115513, -0.01093102, -0.00808716, -0.01019287,
#        -0.00948524, -0.00980854, -0.01103592, -0.00991344, -0.01237488,
#        -0.00997829, -0.0093708 , -0.01264286, -0.00900078, -0.01134205,
#        -0.01047611, -0.01046562, -0.01003456, -0.00995064, -0.01037598,
#        -0.00988007, -0.00991058, -0.01053905, -0.01050472, -0.01052475,
#        -0.0107975 , -0.01057625, -0.00967693, -0.01104546, -0.0083704 ,
#        -0.00822544, -0.00991535, -0.0094862 , -0.0099268 , -0.00915241,
#        -0.00967407, -0.01097775, -0.00966549, -0.01096344, -0.01165867,
#        -0.01037788, -0.00947762, -0.01151562, -0.01064396, -0.01024246,
#        -0.0111866 , -0.01009846, -0.01075077, -0.01127911, -0.01149273],
#       dtype=float32)>

# %% [markdown]
# ## 6. Testing Langevin SMC

# %%
reload(smc)
# Out:
# <module 'langevin_smc' from '/home/karim-tito/sampling-reliability-measure/karimtito_reliability_meassure/langevin_smc.py'>

# %%
epsilons=[0.001,0.01,0.05,0.08,0.1,0.2,0.3]
p_ests=[]
times=[]
for epsilon in epsilons[1:]:
    normal_gen=lambda N: tf.random.normal((N,784))
    V_ = lambda X: V(X,x_0=x_0,model=test_model,epsilon=epsilon, target_class=y_0)
    gradV_ = lambda X: gradV(X,x_0=x_0,model=test_model, target_class=y_0,epsilon=epsilon)
    t=time()
    p_est=smc.LangevinSMCBaseTF(gen=normal_gen, l_kernel=smc.langevin_kernel,V=V_, gradV=gradV_,rho=500,beta_0=0, min_rate=0.5,
    alpha =1,N=50,T = 1,n_max=10000, verbose=2,adapt_func=None,
    step_decay=0.0)
    p_ests.append(p_est)
    t=time()-t
    times.append(t)
# Out:
# Initial time step: dt=0.02413099631667137
# Iter =  1  v_mean =  7.225357  Calls =  150 v_std =  0.09434213
# New time step: dt=0.02413099631667137
# Iter =  2  v_mean =  6.6601434  Calls =  250 v_std =  0.09266721
# New time step: dt=0.02413099631667137
# Iter =  3  v_mean =  6.2632966  Calls =  350 v_std =  0.08701106
# New time step: dt=0.02413099631667137
# Iter =  4  v_mean =  5.9873314  Calls =  450 v_std =  0.083386675
# New time step: dt=0.02413099631667137
# Iter =  5  v_mean =  5.7857146  Calls =  550 v_std =  0.07702056
# New time step: dt=0.02413099631667137
# Iter =  6  v_mean =  5.6323705  Calls =  650 v_std =  0.06944057
# New time step: dt=0.02413099631667137
# Iter =  7  v_mean =  5.515689  Calls =  750 v_std =  0.061810046
# New time step: dt=0.02413099631667137
# Iter =  8  v_mean =  5.42567  Calls =  850 v_std =  0.054019623
# New time step: dt=0.02413099631667137
# Iter =  9  v_mean =  5.3550663  Calls =  950 v_std =  0.047631036
# New time step: dt=0.02413099631667137
# Iter =  10  v_mean =  5.297968  Calls =  1050 v_std =  0.042939574
# New time step: dt=0.02413099631667137
# Iter =  11  v_mean =  5.250689  Calls =  1150 v_std =  0.038307812
# New time step: dt=0.02413099631667137
# Iter =  12  v_mean =  5.211663  Calls =  1250 v_std =  0.035266135
# New time step: dt=0.02413099631667137
# Iter =  13  v_mean =  5.1784573  Calls =  1350 v_std =  0.032351144
# New time step: dt=0.02413099631667137
# Iter =  14  v_mean =  5.1497817  Calls =  1450 v_std =  0.0303888
# New time step: dt=0.02413099631667137
# Iter =  15  v_mean =  5.1253743  Calls =  1550 v_std =  0.029205486
# New time step: dt=0.02413099631667137
# Iter =  16  v_mean =  5.103919  Calls =  1650 v_std =  0.02808251
# New time step: dt=0.02413099631667137
# Iter =  17  v_mean =  5.0854516  Calls =  1750 v_std =  0.027090002
# New time step: dt=0.02413099631667137
# Iter =  18  v_mean =  5.069522  Calls =  1850 v_std =  0.025678448
# New time step: dt=0.02413099631667137
# Iter =  19  v_mean =  5.055513  Calls =  1950 v_std =  0.02432505
# New time step: dt=0.02413099631667137
# Iter =  20  v_mean =  5.0426707  Calls =  2050 v_std =  0.023423249
# New time step: dt=0.02413099631667137
# Iter =  21  v_mean =  5.031207  Calls =  2150 v_std =  0.022978747
# New time step: dt=0.02413099631667137
# Iter =  22  v_mean =  5.020605  Calls =  2250 v_std =  0.022803651
# New time step: dt=0.02413099631667137
# Iter =  23  v_mean =  5.010759  Calls =  2350 v_std =  0.022573974
# New time step: dt=0.02413099631667137
# Iter =  24  v_mean =  5.001764  Calls =  2450 v_std =  0.022196019
# New time step: dt=0.02413099631667137
# Iter =  25  v_mean =  4.9935274  Calls =  2550 v_std =  0.021773204
# New time step: dt=0.02413099631667137
# Iter =  26  v_mean =  4.985914  Calls =  2650 v_std =  0.021302681
# New time step: dt=0.02413099631667137
# Iter =  27  v_mean =  4.9789433  Calls =  2750 v_std =  0.020686753
# New time step: dt=0.02413099631667137
# Iter =  28  v_mean =  4.9725785  Calls =  2850 v_std =  0.019881552
# New time step: dt=0.02413099631667137
# Iter =  29  v_mean =  4.96662  Calls =  2950 v_std =  0.019225756
# New time step: dt=0.02413099631667137
# Iter =  30  v_mean =  4.9609084  Calls =  3050 v_std =  0.018707514
# New time step: dt=0.02413099631667137
# Iter =  31  v_mean =  4.955583  Calls =  3150 v_std =  0.017981533
# New time step: dt=0.02413099631667137
# Iter =  32  v_mean =  4.9506726  Calls =  3250 v_std =  0.01740394
# New time step: dt=0.02413099631667137
# Iter =  33  v_mean =  4.9461093  Calls =  3350 v_std =  0.01703979
# New time step: dt=0.02413099631667137
# Iter =  34  v_mean =  4.9418373  Calls =  3450 v_std =  0.0168386
# New time step: dt=0.02413099631667137
# Iter =  35  v_mean =  4.937793  Calls =  3550 v_std =  0.016663881
# New time step: dt=0.02413099631667137
# Iter =  36  v_mean =  4.934129  Calls =  3650 v_std =  0.016400335
# New time step: dt=0.02413099631667137
# Iter =  37  v_mean =  4.930711  Calls =  3750 v_std =  0.016125787
# New time step: dt=0.02413099631667137
# Iter =  38  v_mean =  4.9274898  Calls =  3850 v_std =  0.015960062
# New time step: dt=0.02413099631667137
# Iter =  39  v_mean =  4.9243126  Calls =  3950 v_std =  0.015817743
# New time step: dt=0.02413099631667137
# Iter =  40  v_mean =  4.921235  Calls =  4050 v_std =  0.015612732
# New time step: dt=0.02413099631667137
# Iter =  41  v_mean =  4.9183617  Calls =  4150 v_std =  0.015483881
# New time step: dt=0.02413099631667137
# Iter =  42  v_mean =  4.9155927  Calls =  4250 v_std =  0.015396673
# New time step: dt=0.02413099631667137
# Iter =  43  v_mean =  4.913047  Calls =  4350 v_std =  0.015374328
# New time step: dt=0.02413099631667137
# Iter =  44  v_mean =  4.9106116  Calls =  4450 v_std =  0.015405502
# New time step: dt=0.02413099631667137
# Iter =  45  v_mean =  4.908242  Calls =  4550 v_std =  0.015485752
# New time step: dt=0.02413099631667137
# Iter =  46  v_mean =  4.9059825  Calls =  4650 v_std =  0.01554707
# New time step: dt=0.02413099631667137
# Iter =  47  v_mean =  4.903806  Calls =  4750 v_std =  0.015623864
# New time step: dt=0.02413099631667137
# Iter =  48  v_mean =  4.9017277  Calls =  4850 v_std =  0.015673416
# New time step: dt=0.02413099631667137
# Iter =  49  v_mean =  4.8997054  Calls =  4950 v_std =  0.015684744
# New time step: dt=0.02413099631667137
# Iter =  50  v_mean =  4.897727  Calls =  5050 v_std =  0.015648745
# New time step: dt=0.02413099631667137
# Iter =  51  v_mean =  4.895813  Calls =  5150 v_std =  0.0156194
# New time step: dt=0.02413099631667137
# Iter =  52  v_mean =  4.8940105  Calls =  5250 v_std =  0.015565606
# New time step: dt=0.02413099631667137
# Iter =  53  v_mean =  4.8922825  Calls =  5350 v_std =  0.015504939
# New time step: dt=0.02413099631667137
# Iter =  54  v_mean =  4.8906093  Calls =  5450 v_std =  0.015466484
# New time step: dt=0.02413099631667137
# Iter =  55  v_mean =  4.88902  Calls =  5550 v_std =  0.015411278
# New time step: dt=0.02413099631667137
# Iter =  56  v_mean =  4.8875237  Calls =  5650 v_std =  0.01530667
# New time step: dt=0.02413099631667137
# Iter =  57  v_mean =  4.886073  Calls =  5750 v_std =  0.01519963
# New time step: dt=0.02413099631667137
# Iter =  58  v_mean =  4.8846807  Calls =  5850 v_std =  0.015080944
# New time step: dt=0.02413099631667137
# Iter =  59  v_mean =  4.883346  Calls =  5950 v_std =  0.014964124
# New time step: dt=0.02413099631667137
# Iter =  60  v_mean =  4.882078  Calls =  6050 v_std =  0.014855919
# New time step: dt=0.02413099631667137
# Iter =  61  v_mean =  4.88087  Calls =  6150 v_std =  0.0147698205
# New time step: dt=0.02413099631667137
# Iter =  62  v_mean =  4.8796926  Calls =  6250 v_std =  0.014710398
# New time step: dt=0.02413099631667137
# Iter =  63  v_mean =  4.8784676  Calls =  6350 v_std =  0.014513119
# New time step: dt=0.02413099631667137
# Iter =  64  v_mean =  4.877291  Calls =  6450 v_std =  0.014288742
# New time step: dt=0.02413099631667137
# Iter =  65  v_mean =  4.8762145  Calls =  6550 v_std =  0.014100152
# New time step: dt=0.02413099631667137
# Iter =  66  v_mean =  4.875147  Calls =  6650 v_std =  0.013899749
# New time step: dt=0.02413099631667137
# Iter =  67  v_mean =  4.874119  Calls =  6750 v_std =  0.0136863375
# New time step: dt=0.02413099631667137
# Iter =  68  v_mean =  4.8730793  Calls =  6850 v_std =  0.013449522
# New time step: dt=0.02413099631667137
# Iter =  69  v_mean =  4.8720107  Calls =  6950 v_std =  0.0132325785
# New time step: dt=0.02413099631667137
# Iter =  70  v_mean =  4.8709126  Calls =  7050 v_std =  0.013035795
# New time step: dt=0.02413099631667137
# Iter =  71  v_mean =  4.8697863  Calls =  7150 v_std =  0.0128906835
# New time step: dt=0.02413099631667137
# Iter =  72  v_mean =  4.8687673  Calls =  7250 v_std =  0.01281271
# New time step: dt=0.02413099631667137
# Iter =  73  v_mean =  4.867847  Calls =  7350 v_std =  0.012739565
# New time step: dt=0.02413099631667137
# Iter =  74  v_mean =  4.867003  Calls =  7450 v_std =  0.012694599
# New time step: dt=0.02413099631667137
# Iter =  75  v_mean =  4.8661757  Calls =  7550 v_std =  0.012619303
# New time step: dt=0.02413099631667137
# Iter =  76  v_mean =  4.865413  Calls =  7650 v_std =  0.012559455
# New time step: dt=0.02413099631667137
# Iter =  77  v_mean =  4.864693  Calls =  7750 v_std =  0.012501965
# New time step: dt=0.02413099631667137
# Iter =  78  v_mean =  4.86399  Calls =  7850 v_std =  0.012388039
# New time step: dt=0.02413099631667137
# Iter =  79  v_mean =  4.8633075  Calls =  7950 v_std =  0.012280586
# New time step: dt=0.02413099631667137
# Iter =  80  v_mean =  4.862653  Calls =  8050 v_std =  0.012158315
# New time step: dt=0.02413099631667137
# Iter =  81  v_mean =  4.8620424  Calls =  8150 v_std =  0.012027878
# New time step: dt=0.02413099631667137
# Iter =  82  v_mean =  4.8614407  Calls =  8250 v_std =  0.011864488
# New time step: dt=0.02413099631667137
# Iter =  83  v_mean =  4.860824  Calls =  8350 v_std =  0.011527494
# New time step: dt=0.02413099631667137
# Iter =  84  v_mean =  4.8601866  Calls =  8450 v_std =  0.011164649
# New time step: dt=0.02413099631667137
# Iter =  85  v_mean =  4.8595796  Calls =  8550 v_std =  0.010975303
# New time step: dt=0.02413099631667137
# Iter =  86  v_mean =  4.858972  Calls =  8650 v_std =  0.010825311
# New time step: dt=0.02413099631667137
# Iter =  87  v_mean =  4.8583865  Calls =  8750 v_std =  0.0107085
# New time step: dt=0.02413099631667137
# Iter =  88  v_mean =  4.85782  Calls =  8850 v_std =  0.010602743
# New time step: dt=0.02413099631667137
# Iter =  89  v_mean =  4.857273  Calls =  8950 v_std =  0.0104980925
# New time step: dt=0.02413099631667137
# Iter =  90  v_mean =  4.856781  Calls =  9050 v_std =  0.010426029
# New time step: dt=0.02413099631667137
# Iter =  91  v_mean =  4.856316  Calls =  9150 v_std =  0.010356174
# New time step: dt=0.02413099631667137
# Iter =  92  v_mean =  4.8558583  Calls =  9250 v_std =  0.010291468
# New time step: dt=0.02413099631667137
# Iter =  93  v_mean =  4.8554015  Calls =  9350 v_std =  0.010219638
# New time step: dt=0.02413099631667137
# Iter =  94  v_mean =  4.854959  Calls =  9450 v_std =  0.010145936
# New time step: dt=0.02413099631667137
# Iter =  95  v_mean =  4.8545113  Calls =  9550 v_std =  0.010065115
# New time step: dt=0.02413099631667137
# Iter =  96  v_mean =  4.8540683  Calls =  9650 v_std =  0.009942462
# New time step: dt=0.02413099631667137
# Iter =  97  v_mean =  4.8535724  Calls =  9750 v_std =  0.009786815
# New time step: dt=0.02413099631667137
# Iter =  98  v_mean =  4.853046  Calls =  9850 v_std =  0.009622835
# New time step: dt=0.02413099631667137
# Iter =  99  v_mean =  4.8525524  Calls =  9950 v_std =  0.009547934
# New time step: dt=0.02413099631667137
# Iter =  100  v_mean =  4.8521247  Calls =  10050 v_std =  0.0095339855
# New time step: dt=0.02413099631667137
# Iter =  101  v_mean =  4.8517423  Calls =  10150 v_std =  0.009517705
# New time step: dt=0.02413099631667137
# Iter =  102  v_mean =  4.851367  Calls =  10250 v_std =  0.009508624
# New time step: dt=0.02413099631667137
# Iter =  103  v_mean =  4.851013  Calls =  10350 v_std =  0.009500655
# New time step: dt=0.02413099631667137
# Iter =  104  v_mean =  4.850679  Calls =  10450 v_std =  0.009489198
# New time step: dt=0.02413099631667137
# Iter =  105  v_mean =  4.85034  Calls =  10550 v_std =  0.009479442
# New time step: dt=0.02413099631667137
# Iter =  106  v_mean =  4.849976  Calls =  10650 v_std =  0.009403712
# New time step: dt=0.02413099631667137
# Iter =  107  v_mean =  4.849618  Calls =  10750 v_std =  0.009325033
# New time step: dt=0.02413099631667137
# Iter =  108  v_mean =  4.8492713  Calls =  10850 v_std =  0.009263819
# New time step: dt=0.02413099631667137
# Iter =  109  v_mean =  4.8489475  Calls =  10950 v_std =  0.009229379
# New time step: dt=0.02413099631667137
# Iter =  110  v_mean =  4.848634  Calls =  11050 v_std =  0.009196419
# New time step: dt=0.02413099631667137
# Iter =  111  v_mean =  4.8483305  Calls =  11150 v_std =  0.009173374
# New time step: dt=0.02413099631667137
# Iter =  112  v_mean =  4.848033  Calls =  11250 v_std =  0.009154826
# New time step: dt=0.02413099631667137
# Iter =  113  v_mean =  4.8477397  Calls =  11350 v_std =  0.009139895
# New time step: dt=0.02413099631667137
# Iter =  114  v_mean =  4.8474426  Calls =  11450 v_std =  0.0091185
# New time step: dt=0.02413099631667137
# Iter =  115  v_mean =  4.847164  Calls =  11550 v_std =  0.009097723
# New time step: dt=0.02413099631667137
# Iter =  116  v_mean =  4.846892  Calls =  11650 v_std =  0.009072722
# New time step: dt=0.02413099631667137
# Iter =  117  v_mean =  4.846619  Calls =  11750 v_std =  0.009045922
# New time step: dt=0.02413099631667137
# Iter =  118  v_mean =  4.846355  Calls =  11850 v_std =  0.009009968
# New time step: dt=0.02413099631667137
# Iter =  119  v_mean =  4.8460937  Calls =  11950 v_std =  0.008980483
# New time step: dt=0.02413099631667137
# Iter =  120  v_mean =  4.845823  Calls =  12050 v_std =  0.0089568775
# New time step: dt=0.02413099631667137
# Iter =  121  v_mean =  4.84555  Calls =  12150 v_std =  0.008916214
# New time step: dt=0.02413099631667137
# Iter =  122  v_mean =  4.845284  Calls =  12250 v_std =  0.008874781
# New time step: dt=0.02413099631667137
# Iter =  123  v_mean =  4.8450165  Calls =  12350 v_std =  0.008836094
# New time step: dt=0.02413099631667137
# Iter =  124  v_mean =  4.844735  Calls =  12450 v_std =  0.008781707
# New time step: dt=0.02413099631667137
# Iter =  125  v_mean =  4.844456  Calls =  12550 v_std =  0.008736015
# New time step: dt=0.02413099631667137
# Iter =  126  v_mean =  4.8441796  Calls =  12650 v_std =  0.008710487
# New time step: dt=0.02413099631667137
# Iter =  127  v_mean =  4.8439136  Calls =  12750 v_std =  0.008688188
# New time step: dt=0.02413099631667137
# Iter =  128  v_mean =  4.843695  Calls =  12850 v_std =  0.008617827
# New time step: dt=0.02413099631667137
# Iter =  129  v_mean =  4.8434906  Calls =  12950 v_std =  0.008574309
# New time step: dt=0.02413099631667137
# Iter =  130  v_mean =  4.8432837  Calls =  13050 v_std =  0.00852238
# New time step: dt=0.02413099631667137
# Iter =  131  v_mean =  4.843089  Calls =  13150 v_std =  0.008491509
# New time step: dt=0.02413099631667137
# Iter =  132  v_mean =  4.842898  Calls =  13250 v_std =  0.008430129
# New time step: dt=0.02413099631667137
# Iter =  133  v_mean =  4.842715  Calls =  13350 v_std =  0.008395567
# New time step: dt=0.02413099631667137
# Iter =  134  v_mean =  4.8425226  Calls =  13450 v_std =  0.0083422605
# New time step: dt=0.02413099631667137
# Iter =  135  v_mean =  4.8423448  Calls =  13550 v_std =  0.008319143
# New time step: dt=0.02413099631667137
# Iter =  136  v_mean =  4.8421664  Calls =  13650 v_std =  0.008282263
# New time step: dt=0.02413099631667137
# Iter =  137  v_mean =  4.841987  Calls =  13750 v_std =  0.008254286
# New time step: dt=0.02413099631667137
# Iter =  138  v_mean =  4.8418007  Calls =  13850 v_std =  0.008200515
# New time step: dt=0.02413099631667137
# Iter =  139  v_mean =  4.841596  Calls =  13950 v_std =  0.008166603
# New time step: dt=0.02413099631667137
# Iter =  140  v_mean =  4.8413863  Calls =  14050 v_std =  0.008143228
# New time step: dt=0.02413099631667137
# Iter =  141  v_mean =  4.841183  Calls =  14150 v_std =  0.008145801
# New time step: dt=0.02413099631667137
# Iter =  142  v_mean =  4.841006  Calls =  14250 v_std =  0.008129871
# New time step: dt=0.02413099631667137
# Iter =  143  v_mean =  4.8408513  Calls =  14350 v_std =  0.0081012705
# New time step: dt=0.02413099631667137
# Iter =  144  v_mean =  4.8406954  Calls =  14450 v_std =  0.008080443
# New time step: dt=0.02413099631667137
# Iter =  145  v_mean =  4.8405514  Calls =  14550 v_std =  0.008063555
# New time step: dt=0.02413099631667137
# Iter =  146  v_mean =  4.8404055  Calls =  14650 v_std =  0.008037478
# New time step: dt=0.02413099631667137
# Iter =  147  v_mean =  4.8402605  Calls =  14750 v_std =  0.008015213
# New time step: dt=0.02413099631667137
# Iter =  148  v_mean =  4.840114  Calls =  14850 v_std =  0.007992006
# New time step: dt=0.02413099631667137
# Iter =  149  v_mean =  4.839978  Calls =  14950 v_std =  0.007978994
# New time step: dt=0.02413099631667137
# Iter =  150  v_mean =  4.8398366  Calls =  15050 v_std =  0.007967443
# New time step: dt=0.02413099631667137
# Iter =  151  v_mean =  4.8396935  Calls =  15150 v_std =  0.007952532
# New time step: dt=0.02413099631667137
# Iter =  152  v_mean =  4.8395576  Calls =  15250 v_std =  0.007946283
# New time step: dt=0.02413099631667137
# Iter =  153  v_mean =  4.839422  Calls =  15350 v_std =  0.007937173
# New time step: dt=0.02413099631667137
# Iter =  154  v_mean =  4.83929  Calls =  15450 v_std =  0.007922903
# New time step: dt=0.02413099631667137
# Iter =  155  v_mean =  4.8391633  Calls =  15550 v_std =  0.007908493
# New time step: dt=0.02413099631667137
# Iter =  156  v_mean =  4.839041  Calls =  15650 v_std =  0.007893324
# New time step: dt=0.02413099631667137
# Iter =  157  v_mean =  4.838921  Calls =  15750 v_std =  0.00788006
# New time step: dt=0.02413099631667137
# Iter =  158  v_mean =  4.8388004  Calls =  15850 v_std =  0.007857195
# New time step: dt=0.02413099631667137
# Iter =  159  v_mean =  4.8386774  Calls =  15950 v_std =  0.007836255
# New time step: dt=0.02413099631667137
# Iter =  160  v_mean =  4.838558  Calls =  16050 v_std =  0.00782163
# New time step: dt=0.02413099631667137
# Iter =  161  v_mean =  4.8384385  Calls =  16150 v_std =  0.0077998266
# New time step: dt=0.02413099631667137
# Iter =  162  v_mean =  4.8383207  Calls =  16250 v_std =  0.0077852495
# New time step: dt=0.02413099631667137
# Iter =  163  v_mean =  4.838193  Calls =  16350 v_std =  0.0077627734
# New time step: dt=0.02413099631667137
# Iter =  164  v_mean =  4.838069  Calls =  16450 v_std =  0.0077417577
# New time step: dt=0.02413099631667137
# Iter =  165  v_mean =  4.837938  Calls =  16550 v_std =  0.007716914
# New time step: dt=0.02413099631667137
# Iter =  166  v_mean =  4.837811  Calls =  16650 v_std =  0.0076965443
# New time step: dt=0.02413099631667137
# Iter =  167  v_mean =  4.8376765  Calls =  16750 v_std =  0.007679857
# New time step: dt=0.02413099631667137
# Iter =  168  v_mean =  4.837549  Calls =  16850 v_std =  0.0076624504
# New time step: dt=0.02413099631667137
# Iter =  169  v_mean =  4.837435  Calls =  16950 v_std =  0.007655294
# New time step: dt=0.02413099631667137
# Iter =  170  v_mean =  4.8373075  Calls =  17050 v_std =  0.007647563
# New time step: dt=0.02413099631667137
# Iter =  171  v_mean =  4.837187  Calls =  17150 v_std =  0.0076319873
# New time step: dt=0.02413099631667137
# Iter =  172  v_mean =  4.837068  Calls =  17250 v_std =  0.007622722
# New time step: dt=0.02413099631667137
# Iter =  173  v_mean =  4.8369503  Calls =  17350 v_std =  0.0076143146
# New time step: dt=0.02413099631667137
# Iter =  174  v_mean =  4.836842  Calls =  17450 v_std =  0.0076032537
# New time step: dt=0.02413099631667137
# Iter =  175  v_mean =  4.8367386  Calls =  17550 v_std =  0.0075938907
# New time step: dt=0.02413099631667137
# Iter =  176  v_mean =  4.8366337  Calls =  17650 v_std =  0.007586938
# New time step: dt=0.02413099631667137
# Iter =  177  v_mean =  4.8365297  Calls =  17750 v_std =  0.00758173
# New time step: dt=0.02413099631667137
# Iter =  178  v_mean =  4.8364244  Calls =  17850 v_std =  0.007574798
# New time step: dt=0.02413099631667137
# Iter =  179  v_mean =  4.8363295  Calls =  17950 v_std =  0.007562049
# New time step: dt=0.02413099631667137
# Iter =  180  v_mean =  4.836229  Calls =  18050 v_std =  0.007547954
# New time step: dt=0.02413099631667137
# Iter =  181  v_mean =  4.836121  Calls =  18150 v_std =  0.0075322296
# New time step: dt=0.02413099631667137
# Iter =  182  v_mean =  4.836009  Calls =  18250 v_std =  0.0075173364
# New time step: dt=0.02413099631667137
# Iter =  183  v_mean =  4.835879  Calls =  18350 v_std =  0.007461798
# New time step: dt=0.02413099631667137
# Iter =  184  v_mean =  4.835742  Calls =  18450 v_std =  0.007406655
# New time step: dt=0.02413099631667137
# Iter =  185  v_mean =  4.8356166  Calls =  18550 v_std =  0.0073632146
# New time step: dt=0.02413099631667137
# Iter =  186  v_mean =  4.8355107  Calls =  18650 v_std =  0.0073376396
# New time step: dt=0.02413099631667137
# Iter =  187  v_mean =  4.835403  Calls =  18750 v_std =  0.0073025734
# New time step: dt=0.02413099631667137
# Iter =  188  v_mean =  4.835296  Calls =  18850 v_std =  0.0072775483
# New time step: dt=0.02413099631667137
# Iter =  189  v_mean =  4.8352013  Calls =  18950 v_std =  0.007255929
# New time step: dt=0.02413099631667137
# Iter =  190  v_mean =  4.8351173  Calls =  19050 v_std =  0.0072405003
# New time step: dt=0.02413099631667137
# Iter =  191  v_mean =  4.835035  Calls =  19150 v_std =  0.0072334753
# New time step: dt=0.02413099631667137
# Iter =  192  v_mean =  4.8349605  Calls =  19250 v_std =  0.007224616
# New time step: dt=0.02413099631667137
# Iter =  193  v_mean =  4.8348885  Calls =  19350 v_std =  0.0072155194
# New time step: dt=0.02413099631667137
# Iter =  194  v_mean =  4.8348236  Calls =  19450 v_std =  0.0072071585
# New time step: dt=0.02413099631667137
# Iter =  195  v_mean =  4.8347564  Calls =  19550 v_std =  0.007199174
# New time step: dt=0.02413099631667137
# Iter =  196  v_mean =  4.8346834  Calls =  19650 v_std =  0.0071894717
# New time step: dt=0.02413099631667137
# Iter =  197  v_mean =  4.834563  Calls =  19750 v_std =  0.0071726367
# New time step: dt=0.02413099631667137
# Iter =  198  v_mean =  4.8344545  Calls =  19850 v_std =  0.0071669878
# New time step: dt=0.02413099631667137
# Iter =  199  v_mean =  4.8343744  Calls =  19950 v_std =  0.0071702683
# New time step: dt=0.02413099631667137
# Iter =  200  v_mean =  4.8343  Calls =  20050 v_std =  0.007172937
# New time step: dt=0.02413099631667137
# Iter =  201  v_mean =  4.834238  Calls =  20150 v_std =  0.0071738185
# New time step: dt=0.02413099631667137
# Iter =  202  v_mean =  4.8341804  Calls =  20250 v_std =  0.0071712635
# New time step: dt=0.02413099631667137
# Iter =  203  v_mean =  4.8341236  Calls =  20350 v_std =  0.0071642785
# New time step: dt=0.02413099631667137
# Iter =  204  v_mean =  4.8340673  Calls =  20450 v_std =  0.00715903
# New time step: dt=0.02413099631667137
# Iter =  205  v_mean =  4.8340106  Calls =  20550 v_std =  0.007156413
# New time step: dt=0.02413099631667137
# Iter =  206  v_mean =  4.83396  Calls =  20650 v_std =  0.0071522924
# New time step: dt=0.02413099631667137
# Iter =  207  v_mean =  4.833906  Calls =  20750 v_std =  0.00715072
# New time step: dt=0.02413099631667137
# Iter =  208  v_mean =  4.8338537  Calls =  20850 v_std =  0.0071442085
# New time step: dt=0.02413099631667137
# Iter =  209  v_mean =  4.8337994  Calls =  20950 v_std =  0.007137893
# New time step: dt=0.02413099631667137
# Iter =  210  v_mean =  4.833743  Calls =  21050 v_std =  0.007131559
# New time step: dt=0.02413099631667137
# Iter =  211  v_mean =  4.833658  Calls =  21150 v_std =  0.007115381
# New time step: dt=0.02413099631667137
# Iter =  212  v_mean =  4.8335786  Calls =  21250 v_std =  0.007106615
# New time step: dt=0.02413099631667137
# Iter =  213  v_mean =  4.8335075  Calls =  21350 v_std =  0.0071071223
# New time step: dt=0.02413099631667137
# Iter =  214  v_mean =  4.833432  Calls =  21450 v_std =  0.0071024247
# New time step: dt=0.02413099631667137
# Iter =  215  v_mean =  4.8333616  Calls =  21550 v_std =  0.0070963353
# New time step: dt=0.02413099631667137
# Iter =  216  v_mean =  4.8332863  Calls =  21650 v_std =  0.007093947
# New time step: dt=0.02413099631667137
# Iter =  217  v_mean =  4.833216  Calls =  21750 v_std =  0.007094629
# New time step: dt=0.02413099631667137
# Iter =  218  v_mean =  4.833154  Calls =  21850 v_std =  0.0070955493
# New time step: dt=0.02413099631667137
# Iter =  219  v_mean =  4.833093  Calls =  21950 v_std =  0.0070971604
# New time step: dt=0.02413099631667137
# Iter =  220  v_mean =  4.833037  Calls =  22050 v_std =  0.0070981937
# New time step: dt=0.02413099631667137
# Iter =  221  v_mean =  4.832983  Calls =  22150 v_std =  0.0070966836
# New time step: dt=0.02413099631667137
# Iter =  222  v_mean =  4.8329253  Calls =  22250 v_std =  0.0070935683
# New time step: dt=0.02413099631667137
# Iter =  223  v_mean =  4.8328676  Calls =  22350 v_std =  0.007081931
# New time step: dt=0.02413099631667137
# Iter =  224  v_mean =  4.8328137  Calls =  22450 v_std =  0.007072523
# New time step: dt=0.02413099631667137
# Iter =  225  v_mean =  4.8327556  Calls =  22550 v_std =  0.007064707
# New time step: dt=0.02413099631667137
# Iter =  226  v_mean =  4.8327036  Calls =  22650 v_std =  0.0070531126
# New time step: dt=0.02413099631667137
# Iter =  227  v_mean =  4.8326497  Calls =  22750 v_std =  0.0070430986
# New time step: dt=0.02413099631667137
# Iter =  228  v_mean =  4.8325987  Calls =  22850 v_std =  0.0070333653
# New time step: dt=0.02413099631667137
# Iter =  229  v_mean =  4.832552  Calls =  22950 v_std =  0.0070256847
# New time step: dt=0.02413099631667137
# Iter =  230  v_mean =  4.832503  Calls =  23050 v_std =  0.0070163226
# New time step: dt=0.02413099631667137
# Iter =  231  v_mean =  4.832458  Calls =  23150 v_std =  0.00700812
# New time step: dt=0.02413099631667137
# Iter =  232  v_mean =  4.8324184  Calls =  23250 v_std =  0.007001889
# New time step: dt=0.02413099631667137
# Iter =  233  v_mean =  4.832375  Calls =  23350 v_std =  0.006994252
# New time step: dt=0.02413099631667137
# Iter =  234  v_mean =  4.8323326  Calls =  23450 v_std =  0.0069879447
# New time step: dt=0.02413099631667137
# Iter =  235  v_mean =  4.8322887  Calls =  23550 v_std =  0.006982278
# New time step: dt=0.02413099631667137
# Iter =  236  v_mean =  4.832247  Calls =  23650 v_std =  0.0069715814
# New time step: dt=0.02413099631667137
# Iter =  237  v_mean =  4.832208  Calls =  23750 v_std =  0.0069716712
# New time step: dt=0.02413099631667137
# Iter =  238  v_mean =  4.8321643  Calls =  23850 v_std =  0.0069670198
# New time step: dt=0.02413099631667137
# Iter =  239  v_mean =  4.8321266  Calls =  23950 v_std =  0.0069583096
# New time step: dt=0.02413099631667137
# Iter =  240  v_mean =  4.832085  Calls =  24050 v_std =  0.0069567333
# New time step: dt=0.02413099631667137
# Iter =  241  v_mean =  4.832048  Calls =  24150 v_std =  0.006950278
# New time step: dt=0.02413099631667137
# Iter =  242  v_mean =  4.83201  Calls =  24250 v_std =  0.0069450205
# New time step: dt=0.02413099631667137
# Iter =  243  v_mean =  4.831969  Calls =  24350 v_std =  0.006944812
# New time step: dt=0.02413099631667137
# Iter =  244  v_mean =  4.8319335  Calls =  24450 v_std =  0.0069450503
# New time step: dt=0.02413099631667137
# Iter =  245  v_mean =  4.831891  Calls =  24550 v_std =  0.006938711
# New time step: dt=0.02413099631667137
# Iter =  246  v_mean =  4.8318415  Calls =  24650 v_std =  0.0069329315
# New time step: dt=0.02413099631667137
# Iter =  247  v_mean =  4.8317957  Calls =  24750 v_std =  0.0069344146
# New time step: dt=0.02413099631667137
# Iter =  248  v_mean =  4.8317347  Calls =  24850 v_std =  0.0069232876
# New time step: dt=0.02413099631667137
# Iter =  249  v_mean =  4.83168  Calls =  24950 v_std =  0.006912408
# New time step: dt=0.02413099631667137
# Iter =  250  v_mean =  4.831629  Calls =  25050 v_std =  0.006912523
# New time step: dt=0.02413099631667137
# Iter =  251  v_mean =  4.8315845  Calls =  25150 v_std =  0.006912037
# New time step: dt=0.02413099631667137
# Iter =  252  v_mean =  4.8315363  Calls =  25250 v_std =  0.0069066985
# New time step: dt=0.02413099631667137
# Iter =  253  v_mean =  4.831479  Calls =  25350 v_std =  0.0068823616
# New time step: dt=0.02413099631667137
# Iter =  254  v_mean =  4.8314033  Calls =  25450 v_std =  0.0068476074
# New time step: dt=0.02413099631667137
# Iter =  255  v_mean =  4.8313375  Calls =  25550 v_std =  0.0068234256
# New time step: dt=0.02413099631667137
# Iter =  256  v_mean =  4.8312864  Calls =  25650 v_std =  0.0068007535
# New time step: dt=0.02413099631667137
# Iter =  257  v_mean =  4.8312335  Calls =  25750 v_std =  0.0067843674
# New time step: dt=0.02413099631667137
# Iter =  258  v_mean =  4.831189  Calls =  25850 v_std =  0.0067773834
# New time step: dt=0.02413099631667137
# Iter =  259  v_mean =  4.83115  Calls =  25950 v_std =  0.0067678657
# New time step: dt=0.02413099631667137
# Iter =  260  v_mean =  4.831114  Calls =  26050 v_std =  0.0067646946
# New time step: dt=0.02413099631667137
# Iter =  261  v_mean =  4.8310757  Calls =  26150 v_std =  0.006759701
# New time step: dt=0.02413099631667137
# Iter =  262  v_mean =  4.831037  Calls =  26250 v_std =  0.006758017
# New time step: dt=0.02413099631667137
# Iter =  263  v_mean =  4.831005  Calls =  26350 v_std =  0.0067535997
# New time step: dt=0.02413099631667137
# Iter =  264  v_mean =  4.8309674  Calls =  26450 v_std =  0.006751263
# New time step: dt=0.02413099631667137
# Iter =  265  v_mean =  4.830932  Calls =  26550 v_std =  0.0067518456
# New time step: dt=0.02413099631667137
# Iter =  266  v_mean =  4.8308973  Calls =  26650 v_std =  0.0067458926
# New time step: dt=0.02413099631667137
# Iter =  267  v_mean =  4.830866  Calls =  26750 v_std =  0.006746557
# New time step: dt=0.02413099631667137
# Iter =  268  v_mean =  4.830836  Calls =  26850 v_std =  0.0067509455
# New time step: dt=0.02413099631667137
# Iter =  269  v_mean =  4.8308043  Calls =  26950 v_std =  0.0067492626
# New time step: dt=0.02413099631667137
# Iter =  270  v_mean =  4.830777  Calls =  27050 v_std =  0.00674671
# New time step: dt=0.02413099631667137
# Iter =  271  v_mean =  4.8307476  Calls =  27150 v_std =  0.006744667
# New time step: dt=0.02413099631667137
# Iter =  272  v_mean =  4.830714  Calls =  27250 v_std =  0.006744239
# New time step: dt=0.02413099631667137
# Iter =  273  v_mean =  4.830688  Calls =  27350 v_std =  0.006743797
# New time step: dt=0.02413099631667137
# Iter =  274  v_mean =  4.830658  Calls =  27450 v_std =  0.006738863
# New time step: dt=0.02413099631667137
# Iter =  275  v_mean =  4.83063  Calls =  27550 v_std =  0.0067472644
# New time step: dt=0.02413099631667137
# Iter =  276  v_mean =  4.8306055  Calls =  27650 v_std =  0.006747891
# New time step: dt=0.02413099631667137
# Iter =  277  v_mean =  4.830577  Calls =  27750 v_std =  0.0067484737
# New time step: dt=0.02413099631667137
# Iter =  278  v_mean =  4.8305492  Calls =  27850 v_std =  0.006743212
# New time step: dt=0.02413099631667137
# Iter =  279  v_mean =  4.830521  Calls =  27950 v_std =  0.00674438
# New time step: dt=0.02413099631667137
# Iter =  280  v_mean =  4.8304944  Calls =  28050 v_std =  0.0067430953
# New time step: dt=0.02413099631667137
# Iter =  281  v_mean =  4.830473  Calls =  28150 v_std =  0.006747841
# New time step: dt=0.02413099631667137
# Iter =  282  v_mean =  4.830448  Calls =  28250 v_std =  0.0067497524
# New time step: dt=0.02413099631667137
# Iter =  283  v_mean =  4.830421  Calls =  28350 v_std =  0.006747493
# New time step: dt=0.02413099631667137
# Iter =  284  v_mean =  4.8303947  Calls =  28450 v_std =  0.006745023
# New time step: dt=0.02413099631667137
# Iter =  285  v_mean =  4.8303747  Calls =  28550 v_std =  0.006743176
# New time step: dt=0.02413099631667137
# Iter =  286  v_mean =  4.8303466  Calls =  28650 v_std =  0.0067455224
# New time step: dt=0.02413099631667137
# Iter =  287  v_mean =  4.8303237  Calls =  28750 v_std =  0.006752105
# New time step: dt=0.02413099631667137
# Iter =  288  v_mean =  4.8303003  Calls =  28850 v_std =  0.006738997
# New time step: dt=0.02413099631667137
# Iter =  289  v_mean =  4.830277  Calls =  28950 v_std =  0.0067398893
# New time step: dt=0.02413099631667137
# Iter =  290  v_mean =  4.83025  Calls =  29050 v_std =  0.006733116
# New time step: dt=0.02413099631667137
# Iter =  291  v_mean =  4.830229  Calls =  29150 v_std =  0.006729529
# New time step: dt=0.02413099631667137
# Iter =  292  v_mean =  4.830203  Calls =  29250 v_std =  0.0067280657
# New time step: dt=0.02413099631667137
# Iter =  293  v_mean =  4.8301787  Calls =  29350 v_std =  0.006726118
# New time step: dt=0.02413099631667137
# Iter =  294  v_mean =  4.8301544  Calls =  29450 v_std =  0.0067214784
# New time step: dt=0.02413099631667137
# Iter =  295  v_mean =  4.830131  Calls =  29550 v_std =  0.0067190877
# New time step: dt=0.02413099631667137
# Iter =  296  v_mean =  4.830107  Calls =  29650 v_std =  0.006718078
# New time step: dt=0.02413099631667137
# Iter =  297  v_mean =  4.830079  Calls =  29750 v_std =  0.006710854
# New time step: dt=0.02413099631667137
# Iter =  298  v_mean =  4.8300533  Calls =  29850 v_std =  0.0067063053
# New time step: dt=0.02413099631667137
# Iter =  299  v_mean =  4.8300343  Calls =  29950 v_std =  0.0067058317
# New time step: dt=0.02413099631667137
# Iter =  300  v_mean =  4.8300033  Calls =  30050 v_std =  0.00670123
# New time step: dt=0.02413099631667137
# Iter =  301  v_mean =  4.829981  Calls =  30150 v_std =  0.006697579
# New time step: dt=0.02413099631667137
# Iter =  302  v_mean =  4.829959  Calls =  30250 v_std =  0.006700098
# New time step: dt=0.02413099631667137
# Iter =  303  v_mean =  4.8299274  Calls =  30350 v_std =  0.0066973222
# New time step: dt=0.02413099631667137
# Iter =  304  v_mean =  4.8299065  Calls =  30450 v_std =  0.006693794
# New time step: dt=0.02413099631667137
# Iter =  305  v_mean =  4.8298845  Calls =  30550 v_std =  0.006693753
# New time step: dt=0.02413099631667137
# Iter =  306  v_mean =  4.829859  Calls =  30650 v_std =  0.0066930307
# New time step: dt=0.02413099631667137
# Iter =  307  v_mean =  4.8298335  Calls =  30750 v_std =  0.006691645
# New time step: dt=0.02413099631667137
# Iter =  308  v_mean =  4.829812  Calls =  30850 v_std =  0.0066887806
# New time step: dt=0.02413099631667137
# Iter =  309  v_mean =  4.829786  Calls =  30950 v_std =  0.006688467
# New time step: dt=0.02413099631667137
# Iter =  310  v_mean =  4.829764  Calls =  31050 v_std =  0.0066881506
# New time step: dt=0.02413099631667137
# Iter =  311  v_mean =  4.829744  Calls =  31150 v_std =  0.0066864123
# New time step: dt=0.02413099631667137
# Iter =  312  v_mean =  4.829723  Calls =  31250 v_std =  0.0066868593
# New time step: dt=0.02413099631667137
# Iter =  313  v_mean =  4.829698  Calls =  31350 v_std =  0.00668708
# New time step: dt=0.02413099631667137
# Iter =  314  v_mean =  4.829675  Calls =  31450 v_std =  0.0066837925
# New time step: dt=0.02413099631667137
# Iter =  315  v_mean =  4.8296485  Calls =  31550 v_std =  0.006681935
# New time step: dt=0.02413099631667137
# Iter =  316  v_mean =  4.8296237  Calls =  31650 v_std =  0.006683924
# New time step: dt=0.02413099631667137
# Iter =  317  v_mean =  4.829594  Calls =  31750 v_std =  0.006679488
# New time step: dt=0.02413099631667137
# Iter =  318  v_mean =  4.829563  Calls =  31850 v_std =  0.0066846027
# New time step: dt=0.02413099631667137
# Iter =  319  v_mean =  4.829531  Calls =  31950 v_std =  0.0066839904
# New time step: dt=0.02413099631667137
# Iter =  320  v_mean =  4.829497  Calls =  32050 v_std =  0.0066853305
# New time step: dt=0.02413099631667137
# Iter =  321  v_mean =  4.829463  Calls =  32150 v_std =  0.0066931387
# New time step: dt=0.02413099631667137
# Iter =  322  v_mean =  4.829442  Calls =  32250 v_std =  0.0066925096
# New time step: dt=0.02413099631667137
# Iter =  323  v_mean =  4.829424  Calls =  32350 v_std =  0.0066901427
# New time step: dt=0.02413099631667137
# Iter =  324  v_mean =  4.829403  Calls =  32450 v_std =  0.0066916323
# New time step: dt=0.02413099631667137
# Iter =  325  v_mean =  4.8293843  Calls =  32550 v_std =  0.0066916114
# New time step: dt=0.02413099631667137
# Iter =  326  v_mean =  4.8293657  Calls =  32650 v_std =  0.0066958107
# New time step: dt=0.02413099631667137
# Iter =  327  v_mean =  4.82935  Calls =  32750 v_std =  0.006690122
# New time step: dt=0.02413099631667137
# Iter =  328  v_mean =  4.829329  Calls =  32850 v_std =  0.0066864816
# New time step: dt=0.02413099631667137
# Iter =  329  v_mean =  4.8293095  Calls =  32950 v_std =  0.0066891657
# New time step: dt=0.02413099631667137
# Iter =  330  v_mean =  4.829289  Calls =  33050 v_std =  0.0066874363
# New time step: dt=0.02413099631667137
# Iter =  331  v_mean =  4.82927  Calls =  33150 v_std =  0.006685752
# New time step: dt=0.02413099631667137
# Iter =  332  v_mean =  4.8292503  Calls =  33250 v_std =  0.0066849645
# New time step: dt=0.02413099631667137
# Iter =  333  v_mean =  4.8292284  Calls =  33350 v_std =  0.0066829408
# New time step: dt=0.02413099631667137
# Iter =  334  v_mean =  4.8292084  Calls =  33450 v_std =  0.006688001
# New time step: dt=0.02413099631667137
# Iter =  335  v_mean =  4.8291855  Calls =  33550 v_std =  0.0066822283
# New time step: dt=0.02413099631667137
# Iter =  336  v_mean =  4.8291597  Calls =  33650 v_std =  0.0066743903
# New time step: dt=0.02413099631667137
# Iter =  337  v_mean =  4.829136  Calls =  33750 v_std =  0.0066721425
# New time step: dt=0.02413099631667137
# Iter =  338  v_mean =  4.8291078  Calls =  33850 v_std =  0.006666518
# New time step: dt=0.02413099631667137
# Iter =  339  v_mean =  4.829073  Calls =  33950 v_std =  0.0066597788
# New time step: dt=0.02413099631667137
# Iter =  340  v_mean =  4.829035  Calls =  34050 v_std =  0.0066546393
# New time step: dt=0.02413099631667137
# Iter =  341  v_mean =  4.8289957  Calls =  34150 v_std =  0.0066524874
# New time step: dt=0.02413099631667137
# Iter =  342  v_mean =  4.828955  Calls =  34250 v_std =  0.0066506565
# New time step: dt=0.02413099631667137
# Iter =  343  v_mean =  4.8289294  Calls =  34350 v_std =  0.0066511068
# New time step: dt=0.02413099631667137
# Iter =  344  v_mean =  4.828907  Calls =  34450 v_std =  0.006654582
# New time step: dt=0.02413099631667137
# Iter =  345  v_mean =  4.82889  Calls =  34550 v_std =  0.006653751
# New time step: dt=0.02413099631667137
# Iter =  346  v_mean =  4.8288755  Calls =  34650 v_std =  0.0066537014
# New time step: dt=0.02413099631667137
# Iter =  347  v_mean =  4.8288574  Calls =  34750 v_std =  0.006653862
# New time step: dt=0.02413099631667137
# Iter =  348  v_mean =  4.82884  Calls =  34850 v_std =  0.006657423
# New time step: dt=0.02413099631667137
# Iter =  349  v_mean =  4.828822  Calls =  34950 v_std =  0.0066633825
# New time step: dt=0.02413099631667137
# Iter =  350  v_mean =  4.828806  Calls =  35050 v_std =  0.00665929
# New time step: dt=0.02413099631667137
# Iter =  351  v_mean =  4.828787  Calls =  35150 v_std =  0.006657918
# New time step: dt=0.02413099631667137
# Iter =  352  v_mean =  4.828773  Calls =  35250 v_std =  0.0066608177
# New time step: dt=0.02413099631667137
# Iter =  353  v_mean =  4.8287582  Calls =  35350 v_std =  0.006659679
# New time step: dt=0.02413099631667137
# Iter =  354  v_mean =  4.828741  Calls =  35450 v_std =  0.0066593536
# New time step: dt=0.02413099631667137
# Iter =  355  v_mean =  4.8287253  Calls =  35550 v_std =  0.0066602128
# New time step: dt=0.02413099631667137
# Iter =  356  v_mean =  4.828711  Calls =  35650 v_std =  0.0066631865
# New time step: dt=0.02413099631667137
# Iter =  357  v_mean =  4.8286943  Calls =  35750 v_std =  0.0066622538
# New time step: dt=0.02413099631667137
# Iter =  358  v_mean =  4.828679  Calls =  35850 v_std =  0.0066573624
# New time step: dt=0.02413099631667137
# Iter =  359  v_mean =  4.828666  Calls =  35950 v_std =  0.006664148
# New time step: dt=0.02413099631667137
# Iter =  360  v_mean =  4.828647  Calls =  36050 v_std =  0.0066655176
# New time step: dt=0.02413099631667137
# Iter =  361  v_mean =  4.828629  Calls =  36150 v_std =  0.006665305
# New time step: dt=0.02413099631667137
# Iter =  362  v_mean =  4.828613  Calls =  36250 v_std =  0.006663035
# New time step: dt=0.02413099631667137
# Iter =  363  v_mean =  4.828594  Calls =  36350 v_std =  0.0066608503
# New time step: dt=0.02413099631667137
# Iter =  364  v_mean =  4.8285766  Calls =  36450 v_std =  0.0066648955
# New time step: dt=0.02413099631667137
# Iter =  365  v_mean =  4.828559  Calls =  36550 v_std =  0.006665412
# New time step: dt=0.02413099631667137
# Iter =  366  v_mean =  4.8285427  Calls =  36650 v_std =  0.0066636326
# New time step: dt=0.02413099631667137
# Iter =  367  v_mean =  4.828522  Calls =  36750 v_std =  0.0066678375
# New time step: dt=0.02413099631667137
# Iter =  368  v_mean =  4.8285055  Calls =  36850 v_std =  0.006666843
# New time step: dt=0.02413099631667137
# Iter =  369  v_mean =  4.828491  Calls =  36950 v_std =  0.006668258
# New time step: dt=0.02413099631667137
# Iter =  370  v_mean =  4.8284755  Calls =  37050 v_std =  0.006669914
# New time step: dt=0.02413099631667137
# Iter =  371  v_mean =  4.828462  Calls =  37150 v_std =  0.006673199
# New time step: dt=0.02413099631667137
# Iter =  372  v_mean =  4.8284473  Calls =  37250 v_std =  0.0066740275
# New time step: dt=0.02413099631667137
# Iter =  373  v_mean =  4.8284307  Calls =  37350 v_std =  0.006674387
# New time step: dt=0.02413099631667137
# Iter =  374  v_mean =  4.828411  Calls =  37450 v_std =  0.0066720317
# New time step: dt=0.02413099631667137
# Iter =  375  v_mean =  4.8283944  Calls =  37550 v_std =  0.0066754688
# New time step: dt=0.02413099631667137
# Iter =  376  v_mean =  4.8283777  Calls =  37650 v_std =  0.006676952
# New time step: dt=0.02413099631667137
# Iter =  377  v_mean =  4.828361  Calls =  37750 v_std =  0.0066740727
# New time step: dt=0.02413099631667137
# Iter =  378  v_mean =  4.8283467  Calls =  37850 v_std =  0.0066769053
# New time step: dt=0.02413099631667137
# Iter =  379  v_mean =  4.8283315  Calls =  37950 v_std =  0.0066813244
# New time step: dt=0.02413099631667137
# Iter =  380  v_mean =  4.828315  Calls =  38050 v_std =  0.0066829813
# New time step: dt=0.02413099631667137
# Iter =  381  v_mean =  4.8282986  Calls =  38150 v_std =  0.006682612
# New time step: dt=0.02413099631667137
# Iter =  382  v_mean =  4.828282  Calls =  38250 v_std =  0.006682864
# New time step: dt=0.02413099631667137
# Iter =  383  v_mean =  4.8282604  Calls =  38350 v_std =  0.0066825473
# New time step: dt=0.02413099631667137
# Iter =  384  v_mean =  4.8282456  Calls =  38450 v_std =  0.0066818143
# New time step: dt=0.02413099631667137
# Iter =  385  v_mean =  4.8282237  Calls =  38550 v_std =  0.0066801715
# New time step: dt=0.02413099631667137
# Iter =  386  v_mean =  4.8282013  Calls =  38650 v_std =  0.006677824
# New time step: dt=0.02413099631667137
# Iter =  387  v_mean =  4.828183  Calls =  38750 v_std =  0.006677055
# New time step: dt=0.02413099631667137
# Iter =  388  v_mean =  4.828165  Calls =  38850 v_std =  0.0066757817
# New time step: dt=0.02413099631667137
# Iter =  389  v_mean =  4.828145  Calls =  38950 v_std =  0.0066727432
# New time step: dt=0.02413099631667137
# Iter =  390  v_mean =  4.828132  Calls =  39050 v_std =  0.006676085
# New time step: dt=0.02413099631667137
# Iter =  391  v_mean =  4.828122  Calls =  39150 v_std =  0.0066772653
# New time step: dt=0.02413099631667137
# Iter =  392  v_mean =  4.8281064  Calls =  39250 v_std =  0.0066840937
# New time step: dt=0.02413099631667137
# Iter =  393  v_mean =  4.828093  Calls =  39350 v_std =  0.006682108
# New time step: dt=0.02413099631667137
# Iter =  394  v_mean =  4.8280787  Calls =  39450 v_std =  0.006681235
# New time step: dt=0.02413099631667137
# Iter =  395  v_mean =  4.8280687  Calls =  39550 v_std =  0.0066819396
# New time step: dt=0.02413099631667137
# Iter =  396  v_mean =  4.828055  Calls =  39650 v_std =  0.0066825785
# New time step: dt=0.02413099631667137
# Iter =  397  v_mean =  4.828044  Calls =  39750 v_std =  0.006682386
# New time step: dt=0.02413099631667137
# Iter =  398  v_mean =  4.828034  Calls =  39850 v_std =  0.0066843326
# New time step: dt=0.02413099631667137
# Iter =  399  v_mean =  4.8280206  Calls =  39950 v_std =  0.006684148
# New time step: dt=0.02413099631667137
# Iter =  400  v_mean =  4.8280067  Calls =  40050 v_std =  0.00668427
# New time step: dt=0.02413099631667137
# Iter =  401  v_mean =  4.8279967  Calls =  40150 v_std =  0.0066877403
# New time step: dt=0.02413099631667137
# Iter =  402  v_mean =  4.827983  Calls =  40250 v_std =  0.0066858637
# New time step: dt=0.02413099631667137
# Iter =  403  v_mean =  4.827971  Calls =  40350 v_std =  0.006687089
# New time step: dt=0.02413099631667137
# Iter =  404  v_mean =  4.8279605  Calls =  40450 v_std =  0.006689605
# New time step: dt=0.02413099631667137
# Iter =  405  v_mean =  4.827948  Calls =  40550 v_std =  0.0066911555
# New time step: dt=0.02413099631667137
# Iter =  406  v_mean =  4.827938  Calls =  40650 v_std =  0.006696601
# New time step: dt=0.02413099631667137
# Iter =  407  v_mean =  4.8279247  Calls =  40750 v_std =  0.006692986
# New time step: dt=0.02413099631667137
# Iter =  408  v_mean =  4.8279176  Calls =  40850 v_std =  0.0066922666
# New time step: dt=0.02413099631667137
# Iter =  409  v_mean =  4.8279047  Calls =  40950 v_std =  0.0066938284
# New time step: dt=0.02413099631667137
# Iter =  410  v_mean =  4.827894  Calls =  41050 v_std =  0.006694121
# New time step: dt=0.02413099631667137
# Iter =  411  v_mean =  4.8278837  Calls =  41150 v_std =  0.006693466
# New time step: dt=0.02413099631667137
# Iter =  412  v_mean =  4.827872  Calls =  41250 v_std =  0.006693024
# New time step: dt=0.02413099631667137
# Iter =  413  v_mean =  4.8278627  Calls =  41350 v_std =  0.0066961055
# New time step: dt=0.02413099631667137
# Iter =  414  v_mean =  4.827851  Calls =  41450 v_std =  0.0066995393
# New time step: dt=0.02413099631667137
# Iter =  415  v_mean =  4.827838  Calls =  41550 v_std =  0.0067016305
# New time step: dt=0.02413099631667137
# Iter =  416  v_mean =  4.8278294  Calls =  41650 v_std =  0.0066980906
# New time step: dt=0.02413099631667137
# Iter =  417  v_mean =  4.8278184  Calls =  41750 v_std =  0.006697005
# New time step: dt=0.02413099631667137
# Iter =  418  v_mean =  4.8278074  Calls =  41850 v_std =  0.0067013176
# New time step: dt=0.02413099631667137
# Iter =  419  v_mean =  4.827794  Calls =  41950 v_std =  0.006702224
# New time step: dt=0.02413099631667137
# Iter =  420  v_mean =  4.8277845  Calls =  42050 v_std =  0.006700522
# New time step: dt=0.02413099631667137
# Iter =  421  v_mean =  4.8277736  Calls =  42150 v_std =  0.0067016636
# New time step: dt=0.02413099631667137
# Iter =  422  v_mean =  4.8277617  Calls =  42250 v_std =  0.0067031705
# New time step: dt=0.02413099631667137
# Iter =  423  v_mean =  4.8277006  Calls =  42350 v_std =  0.0066393423
# New time step: dt=0.02413099631667137
# Iter =  424  v_mean =  4.827582  Calls =  42450 v_std =  0.00655851
# New time step: dt=0.02413099631667137
# Iter =  425  v_mean =  4.8275175  Calls =  42550 v_std =  0.0065541454
# New time step: dt=0.02413099631667137
# Iter =  426  v_mean =  4.827488  Calls =  42650 v_std =  0.0065573035
# New time step: dt=0.02413099631667137
# Iter =  427  v_mean =  4.8274665  Calls =  42750 v_std =  0.0065586157
# New time step: dt=0.02413099631667137
# Iter =  428  v_mean =  4.827453  Calls =  42850 v_std =  0.0065681883
# New time step: dt=0.02413099631667137
# Iter =  429  v_mean =  4.827439  Calls =  42950 v_std =  0.006563607
# New time step: dt=0.02413099631667137
# Iter =  430  v_mean =  4.8274245  Calls =  43050 v_std =  0.006565544
# New time step: dt=0.02413099631667137
# Iter =  431  v_mean =  4.827415  Calls =  43150 v_std =  0.0065658754
# New time step: dt=0.02413099631667137
# Iter =  432  v_mean =  4.8274064  Calls =  43250 v_std =  0.006564233
# New time step: dt=0.02413099631667137
# Iter =  433  v_mean =  4.827392  Calls =  43350 v_std =  0.0065669687
# New time step: dt=0.02413099631667137
# Iter =  434  v_mean =  4.827382  Calls =  43450 v_std =  0.0065661366
# New time step: dt=0.02413099631667137
# Iter =  435  v_mean =  4.8273735  Calls =  43550 v_std =  0.0065634386
# New time step: dt=0.02413099631667137
# Iter =  436  v_mean =  4.8273625  Calls =  43650 v_std =  0.0065671974
# New time step: dt=0.02413099631667137
# Iter =  437  v_mean =  4.8273525  Calls =  43750 v_std =  0.0065677264
# New time step: dt=0.02413099631667137
# Iter =  438  v_mean =  4.8273454  Calls =  43850 v_std =  0.006570818
# New time step: dt=0.02413099631667137
# Iter =  439  v_mean =  4.8273363  Calls =  43950 v_std =  0.0065682014
# New time step: dt=0.02413099631667137
# Iter =  440  v_mean =  4.8273253  Calls =  44050 v_std =  0.0065656235
# New time step: dt=0.02413099631667137
# Iter =  441  v_mean =  4.8273144  Calls =  44150 v_std =  0.0065657613
# New time step: dt=0.02413099631667137
# Iter =  442  v_mean =  4.827306  Calls =  44250 v_std =  0.006565976
# New time step: dt=0.02413099631667137
# Iter =  443  v_mean =  4.8272963  Calls =  44350 v_std =  0.0065639173
# New time step: dt=0.02413099631667137
# Iter =  444  v_mean =  4.8272867  Calls =  44450 v_std =  0.006562419
# New time step: dt=0.02413099631667137
# Iter =  445  v_mean =  4.8272777  Calls =  44550 v_std =  0.0065692766
# New time step: dt=0.02413099631667137
# Iter =  446  v_mean =  4.827268  Calls =  44650 v_std =  0.0065691196
# New time step: dt=0.02413099631667137
# Iter =  447  v_mean =  4.827259  Calls =  44750 v_std =  0.0065673445
# New time step: dt=0.02413099631667137
# ...
# Iter =  9863  v_mean =  4.8231497  Calls =  986350 v_std =  0.006078455
# New time step: dt=0.02413099631667137
# Iter =  9864  v_mean =  4.823148  Calls =  986450 v_std =  0.0060767797
# New time step: dt=0.02413099631667137
# Iter =  9865  v_mean =  4.8231454  Calls =  986550 v_std =  0.006078842
# New time step: dt=0.02413099631667137
# Iter =  9866  v_mean =  4.823149  Calls =  986650 v_std =  0.0060791285
# New time step: dt=0.02413099631667137
# Iter =  9867  v_mean =  4.8231506  Calls =  986750 v_std =  0.0060777944
# New time step: dt=0.02413099631667137
# Iter =  9868  v_mean =  4.8231483  Calls =  986850 v_std =  0.006075579
# New time step: dt=0.02413099631667137
# Iter =  9869  v_mean =  4.823146  Calls =  986950 v_std =  0.006079558
# New time step: dt=0.02413099631667137
# Iter =  9870  v_mean =  4.8231487  Calls =  987050 v_std =  0.0060809245
# New time step: dt=0.02413099631667137
# Iter =  9871  v_mean =  4.8231497  Calls =  987150 v_std =  0.0060816244
# New time step: dt=0.02413099631667137
# Iter =  9872  v_mean =  4.8231483  Calls =  987250 v_std =  0.0060795927
# New time step: dt=0.02413099631667137
# Iter =  9873  v_mean =  4.8231463  Calls =  987350 v_std =  0.006079789
# New time step: dt=0.02413099631667137
# Iter =  9874  v_mean =  4.8231483  Calls =  987450 v_std =  0.0060785757
# New time step: dt=0.02413099631667137
# Iter =  9875  v_mean =  4.82315  Calls =  987550 v_std =  0.0060759457
# New time step: dt=0.02413099631667137
# Iter =  9876  v_mean =  4.8231487  Calls =  987650 v_std =  0.0060805418
# New time step: dt=0.02413099631667137
# Iter =  9877  v_mean =  4.8231463  Calls =  987750 v_std =  0.0060838005
# New time step: dt=0.02413099631667137
# Iter =  9878  v_mean =  4.82315  Calls =  987850 v_std =  0.006081897
# New time step: dt=0.02413099631667137
# Iter =  9879  v_mean =  4.82315  Calls =  987950 v_std =  0.006080458
# New time step: dt=0.02413099631667137
# Iter =  9880  v_mean =  4.823147  Calls =  988050 v_std =  0.006077352
# New time step: dt=0.02413099631667137
# Iter =  9881  v_mean =  4.8231487  Calls =  988150 v_std =  0.0060783443
# New time step: dt=0.02413099631667137
# Iter =  9882  v_mean =  4.823149  Calls =  988250 v_std =  0.00608087
# New time step: dt=0.02413099631667137
# Iter =  9883  v_mean =  4.823147  Calls =  988350 v_std =  0.0060777003
# New time step: dt=0.02413099631667137
# Iter =  9884  v_mean =  4.8231487  Calls =  988450 v_std =  0.006078894
# New time step: dt=0.02413099631667137
# Iter =  9885  v_mean =  4.823148  Calls =  988550 v_std =  0.006076829
# New time step: dt=0.02413099631667137
# Iter =  9886  v_mean =  4.8231487  Calls =  988650 v_std =  0.00607795
# New time step: dt=0.02413099631667137
# Iter =  9887  v_mean =  4.82315  Calls =  988750 v_std =  0.006078962
# New time step: dt=0.02413099631667137
# Iter =  9888  v_mean =  4.8231463  Calls =  988850 v_std =  0.0060784975
# New time step: dt=0.02413099631667137
# Iter =  9889  v_mean =  4.823145  Calls =  988950 v_std =  0.006075302
# New time step: dt=0.02413099631667137
# Iter =  9890  v_mean =  4.8231487  Calls =  989050 v_std =  0.0060795783
# New time step: dt=0.02413099631667137
# Iter =  9891  v_mean =  4.82315  Calls =  989150 v_std =  0.006078233
# New time step: dt=0.02413099631667137
# Iter =  9892  v_mean =  4.823148  Calls =  989250 v_std =  0.0060772398
# New time step: dt=0.02413099631667137
# Iter =  9893  v_mean =  4.823148  Calls =  989350 v_std =  0.006077766
# New time step: dt=0.02413099631667137
# Iter =  9894  v_mean =  4.823149  Calls =  989450 v_std =  0.006078174
# New time step: dt=0.02413099631667137
# Iter =  9895  v_mean =  4.823149  Calls =  989550 v_std =  0.0060831103
# New time step: dt=0.02413099631667137
# Iter =  9896  v_mean =  4.8231487  Calls =  989650 v_std =  0.006085352
# New time step: dt=0.02413099631667137
# Iter =  9897  v_mean =  4.823147  Calls =  989750 v_std =  0.006083221
# New time step: dt=0.02413099631667137
# Iter =  9898  v_mean =  4.823149  Calls =  989850 v_std =  0.0060792505
# New time step: dt=0.02413099631667137
# Iter =  9899  v_mean =  4.82315  Calls =  989950 v_std =  0.006077651
# New time step: dt=0.02413099631667137
# Iter =  9900  v_mean =  4.8231463  Calls =  990050 v_std =  0.006076525
# New time step: dt=0.02413099631667137
# Iter =  9901  v_mean =  4.8231463  Calls =  990150 v_std =  0.0060801012
# New time step: dt=0.02413099631667137
# Iter =  9902  v_mean =  4.823149  Calls =  990250 v_std =  0.0060785143
# New time step: dt=0.02413099631667137
# Iter =  9903  v_mean =  4.82315  Calls =  990350 v_std =  0.006077894
# New time step: dt=0.02413099631667137
# Iter =  9904  v_mean =  4.823148  Calls =  990450 v_std =  0.006078786
# New time step: dt=0.02413099631667137
# Iter =  9905  v_mean =  4.823148  Calls =  990550 v_std =  0.00607996
# New time step: dt=0.02413099631667137
# Iter =  9906  v_mean =  4.8231463  Calls =  990650 v_std =  0.0060781664
# New time step: dt=0.02413099631667137
# Iter =  9907  v_mean =  4.823148  Calls =  990750 v_std =  0.00607789
# New time step: dt=0.02413099631667137
# Iter =  9908  v_mean =  4.823148  Calls =  990850 v_std =  0.0060768435
# New time step: dt=0.02413099631667137
# Iter =  9909  v_mean =  4.823148  Calls =  990950 v_std =  0.0060833693
# New time step: dt=0.02413099631667137
# Iter =  9910  v_mean =  4.82315  Calls =  991050 v_std =  0.006083729
# New time step: dt=0.02413099631667137
# Iter =  9911  v_mean =  4.823149  Calls =  991150 v_std =  0.006083397
# New time step: dt=0.02413099631667137
# Iter =  9912  v_mean =  4.823148  Calls =  991250 v_std =  0.0060813203
# New time step: dt=0.02413099631667137
# Iter =  9913  v_mean =  4.823147  Calls =  991350 v_std =  0.0060787904
# New time step: dt=0.02413099631667137
# Iter =  9914  v_mean =  4.823149  Calls =  991450 v_std =  0.0060760137
# New time step: dt=0.02413099631667137
# Iter =  9915  v_mean =  4.823149  Calls =  991550 v_std =  0.006078824
# New time step: dt=0.02413099631667137
# Iter =  9916  v_mean =  4.8231473  Calls =  991650 v_std =  0.006077779
# New time step: dt=0.02413099631667137
# Iter =  9917  v_mean =  4.8231473  Calls =  991750 v_std =  0.0060790465
# New time step: dt=0.02413099631667137
# Iter =  9918  v_mean =  4.8231473  Calls =  991850 v_std =  0.006078131
# New time step: dt=0.02413099631667137
# Iter =  9919  v_mean =  4.8231483  Calls =  991950 v_std =  0.0060765967
# New time step: dt=0.02413099631667137
# Iter =  9920  v_mean =  4.8231483  Calls =  992050 v_std =  0.0060800295
# New time step: dt=0.02413099631667137
# Iter =  9921  v_mean =  4.823149  Calls =  992150 v_std =  0.0060850712
# New time step: dt=0.02413099631667137
# Iter =  9922  v_mean =  4.8231483  Calls =  992250 v_std =  0.0060835923
# New time step: dt=0.02413099631667137
# Iter =  9923  v_mean =  4.8231506  Calls =  992350 v_std =  0.006079996
# New time step: dt=0.02413099631667137
# Iter =  9924  v_mean =  4.8231463  Calls =  992450 v_std =  0.006077764
# New time step: dt=0.02413099631667137
# Iter =  9925  v_mean =  4.823147  Calls =  992550 v_std =  0.0060774097
# New time step: dt=0.02413099631667137
# Iter =  9926  v_mean =  4.8231506  Calls =  992650 v_std =  0.0060802675
# New time step: dt=0.02413099631667137
# Iter =  9927  v_mean =  4.823149  Calls =  992750 v_std =  0.006078247
# New time step: dt=0.02413099631667137
# Iter =  9928  v_mean =  4.823148  Calls =  992850 v_std =  0.0060767955
# New time step: dt=0.02413099631667137
# Iter =  9929  v_mean =  4.8231483  Calls =  992950 v_std =  0.0060781864
# New time step: dt=0.02413099631667137
# Iter =  9930  v_mean =  4.823148  Calls =  993050 v_std =  0.0060808104
# New time step: dt=0.02413099631667137
# Iter =  9931  v_mean =  4.823148  Calls =  993150 v_std =  0.0060768877
# New time step: dt=0.02413099631667137
# Iter =  9932  v_mean =  4.823148  Calls =  993250 v_std =  0.0060783364
# New time step: dt=0.02413099631667137
# Iter =  9933  v_mean =  4.823147  Calls =  993350 v_std =  0.0060767145
# New time step: dt=0.02413099631667137
# Iter =  9934  v_mean =  4.823149  Calls =  993450 v_std =  0.006079048
# New time step: dt=0.02413099631667137
# Iter =  9935  v_mean =  4.8231487  Calls =  993550 v_std =  0.0060795015
# New time step: dt=0.02413099631667137
# Iter =  9936  v_mean =  4.8231463  Calls =  993650 v_std =  0.0060785664
# New time step: dt=0.02413099631667137
# Iter =  9937  v_mean =  4.823146  Calls =  993750 v_std =  0.0060762153
# New time step: dt=0.02413099631667137
# Iter =  9938  v_mean =  4.8231506  Calls =  993850 v_std =  0.006078603
# New time step: dt=0.02413099631667137
# Iter =  9939  v_mean =  4.8231506  Calls =  993950 v_std =  0.006080314
# New time step: dt=0.02413099631667137
# Iter =  9940  v_mean =  4.823148  Calls =  994050 v_std =  0.006081849
# New time step: dt=0.02413099631667137
# Iter =  9941  v_mean =  4.823146  Calls =  994150 v_std =  0.0060807164
# New time step: dt=0.02413099631667137
# Iter =  9942  v_mean =  4.8231483  Calls =  994250 v_std =  0.006079443
# New time step: dt=0.02413099631667137
# Iter =  9943  v_mean =  4.82315  Calls =  994350 v_std =  0.006076974
# New time step: dt=0.02413099631667137
# Iter =  9944  v_mean =  4.823147  Calls =  994450 v_std =  0.0060771224
# New time step: dt=0.02413099631667137
# Iter =  9945  v_mean =  4.823148  Calls =  994550 v_std =  0.0060813488
# New time step: dt=0.02413099631667137
# Iter =  9946  v_mean =  4.8231483  Calls =  994650 v_std =  0.0060780575
# New time step: dt=0.02413099631667137
# Iter =  9947  v_mean =  4.8231487  Calls =  994750 v_std =  0.0060763503
# New time step: dt=0.02413099631667137
# Iter =  9948  v_mean =  4.8231483  Calls =  994850 v_std =  0.006077204
# New time step: dt=0.02413099631667137
# Iter =  9949  v_mean =  4.823146  Calls =  994950 v_std =  0.0060798717
# New time step: dt=0.02413099631667137
# Iter =  9950  v_mean =  4.823149  Calls =  995050 v_std =  0.0060780616
# New time step: dt=0.02413099631667137
# Iter =  9951  v_mean =  4.823148  Calls =  995150 v_std =  0.0060779504
# New time step: dt=0.02413099631667137
# Iter =  9952  v_mean =  4.8231473  Calls =  995250 v_std =  0.0060760975
# New time step: dt=0.02413099631667137
# Iter =  9953  v_mean =  4.823148  Calls =  995350 v_std =  0.00607858
# New time step: dt=0.02413099631667137
# Iter =  9954  v_mean =  4.8231473  Calls =  995450 v_std =  0.006081174
# New time step: dt=0.02413099631667137
# Iter =  9955  v_mean =  4.8231483  Calls =  995550 v_std =  0.006082247
# New time step: dt=0.02413099631667137
# Iter =  9956  v_mean =  4.8231487  Calls =  995650 v_std =  0.0060806912
# New time step: dt=0.02413099631667137
# Iter =  9957  v_mean =  4.823146  Calls =  995750 v_std =  0.0060782866
# New time step: dt=0.02413099631667137
# Iter =  9958  v_mean =  4.823149  Calls =  995850 v_std =  0.006078192
# New time step: dt=0.02413099631667137
# Iter =  9959  v_mean =  4.823149  Calls =  995950 v_std =  0.006077584
# New time step: dt=0.02413099631667137
# Iter =  9960  v_mean =  4.823145  Calls =  996050 v_std =  0.006079743
# New time step: dt=0.02413099631667137
# Iter =  9961  v_mean =  4.823148  Calls =  996150 v_std =  0.0060791443
# New time step: dt=0.02413099631667137
# Iter =  9962  v_mean =  4.8231487  Calls =  996250 v_std =  0.006077956
# New time step: dt=0.02413099631667137
# Iter =  9963  v_mean =  4.823147  Calls =  996350 v_std =  0.0060762726
# New time step: dt=0.02413099631667137
# Iter =  9964  v_mean =  4.8231483  Calls =  996450 v_std =  0.006078986
# New time step: dt=0.02413099631667137
# Iter =  9965  v_mean =  4.823148  Calls =  996550 v_std =  0.006079855
# New time step: dt=0.02413099631667137
# Iter =  9966  v_mean =  4.8231483  Calls =  996650 v_std =  0.0060831453
# New time step: dt=0.02413099631667137
# Iter =  9967  v_mean =  4.8231487  Calls =  996750 v_std =  0.0060798926
# New time step: dt=0.02413099631667137
# Iter =  9968  v_mean =  4.8231473  Calls =  996850 v_std =  0.006080285
# New time step: dt=0.02413099631667137
# Iter =  9969  v_mean =  4.823146  Calls =  996950 v_std =  0.006078158
# New time step: dt=0.02413099631667137
# Iter =  9970  v_mean =  4.8231506  Calls =  997050 v_std =  0.0060757343
# New time step: dt=0.02413099631667137
# Iter =  9971  v_mean =  4.823148  Calls =  997150 v_std =  0.0060801134
# New time step: dt=0.02413099631667137
# Iter =  9972  v_mean =  4.823145  Calls =  997250 v_std =  0.006079448
# New time step: dt=0.02413099631667137
# Iter =  9973  v_mean =  4.8231454  Calls =  997350 v_std =  0.0060759163
# New time step: dt=0.02413099631667137
# Iter =  9974  v_mean =  4.8231487  Calls =  997450 v_std =  0.0060781417
# New time step: dt=0.02413099631667137
# Iter =  9975  v_mean =  4.8231487  Calls =  997550 v_std =  0.0060793688
# New time step: dt=0.02413099631667137
# Iter =  9976  v_mean =  4.823148  Calls =  997650 v_std =  0.0060777282
# New time step: dt=0.02413099631667137
# Iter =  9977  v_mean =  4.823148  Calls =  997750 v_std =  0.0060878852
# New time step: dt=0.02413099631667137
# Iter =  9978  v_mean =  4.823148  Calls =  997850 v_std =  0.0060830084
# New time step: dt=0.02413099631667137
# Iter =  9979  v_mean =  4.8231483  Calls =  997950 v_std =  0.0060787895
# New time step: dt=0.02413099631667137
# Iter =  9980  v_mean =  4.8231487  Calls =  998050 v_std =  0.006077481
# New time step: dt=0.02413099631667137
# Iter =  9981  v_mean =  4.823147  Calls =  998150 v_std =  0.0060785045
# New time step: dt=0.02413099631667137
# Iter =  9982  v_mean =  4.823148  Calls =  998250 v_std =  0.0060802377
# New time step: dt=0.02413099631667137
# Iter =  9983  v_mean =  4.823149  Calls =  998350 v_std =  0.006078348
# New time step: dt=0.02413099631667137
# Iter =  9984  v_mean =  4.823148  Calls =  998450 v_std =  0.0060758633
# New time step: dt=0.02413099631667137
# Iter =  9985  v_mean =  4.823146  Calls =  998550 v_std =  0.006078598
# New time step: dt=0.02413099631667137
# Iter =  9986  v_mean =  4.8231506  Calls =  998650 v_std =  0.0060791275
# New time step: dt=0.02413099631667137
# Iter =  9987  v_mean =  4.823147  Calls =  998750 v_std =  0.0060773687
# New time step: dt=0.02413099631667137
# Iter =  9988  v_mean =  4.8231463  Calls =  998850 v_std =  0.0060789064
# New time step: dt=0.02413099631667137
# Iter =  9989  v_mean =  4.823146  Calls =  998950 v_std =  0.0060772514
# New time step: dt=0.02413099631667137
# Iter =  9990  v_mean =  4.8231483  Calls =  999050 v_std =  0.006080918
# New time step: dt=0.02413099631667137
# Iter =  9991  v_mean =  4.8231497  Calls =  999150 v_std =  0.0060835173
# New time step: dt=0.02413099631667137
# Iter =  9992  v_mean =  4.823149  Calls =  999250 v_std =  0.00608364
# New time step: dt=0.02413099631667137
# Iter =  9993  v_mean =  4.823148  Calls =  999350 v_std =  0.0060807928
# New time step: dt=0.02413099631667137
# Iter =  9994  v_mean =  4.8231497  Calls =  999450 v_std =  0.006078112
# New time step: dt=0.02413099631667137
# Iter =  9995  v_mean =  4.823147  Calls =  999550 v_std =  0.006076392
# New time step: dt=0.02413099631667137
# Iter =  9996  v_mean =  4.8231463  Calls =  999650 v_std =  0.0060810205
# New time step: dt=0.02413099631667137
# Iter =  9997  v_mean =  4.823147  Calls =  999750 v_std =  0.006079201
# New time step: dt=0.02413099631667137
# Iter =  9998  v_mean =  4.8231483  Calls =  999850 v_std =  0.006077898
# New time step: dt=0.02413099631667137
# Iter =  9999  v_mean =  4.8231487  Calls =  999950 v_std =  0.006077279
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-78-e372e1c09b57> in <module>
#       9     p_est=smc.LangevinSMCBaseTF(gen=normal_gen, l_kernel=smc.langevin_kernel,V=V_, gradV=gradV_,rho=500,beta_0=0, min_rate=0.5,
#      10     alpha =1,N=50,T = 1,n_max=10000, verbose=2,adapt_func=None,
# ---> 11     step_decay=0.0)
#      12     p_ests.append(p_est)
#      13     t=time()-t
#
# ~/sampling-reliability-measure/karimtito_reliability_meassure/langevin_smc.py in LangevinSMCBaseTF(gen, l_kernel, V, gradV, rho, beta_0, min_rate, alpha, N, T, n_max, step_decay, verbose, adapt_func)
#     233         n += 1 # increases iteration number
#     234         if n >=n_max:
# --> 235             raise RuntimeError('The estimator failed. Increase n_max?')
#     236
#     237         for t in range(T):
#
# RuntimeError: The estimator failed. Increase n_max?

# %% [markdown]
# ## 7. Adversarial attacks comparison

# %%
fmodel = fb.TensorFlowModel(model=test_model, bounds=(0,1))
# Out:
# WARNING:tensorflow:From /home/karim-tito/miniconda3/envs/deep_learning_env/lib/python3.7/site-packages/foolbox/models/tensorflow.py:13: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# WARNING:tensorflow:From /home/karim-tito/miniconda3/envs/deep_learning_env/lib/python3.7/site-packages/foolbox/models/tensorflow.py:13: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.

# %%
attack =fb.attacks.LinfPGD()

# %%
epsilons = [0.001, 0.005, 0.01, 0.03, 0.1, 0.3, 0.5, 1.0]
_, advs, success = attack(fmodel, X_correct, label_correct, epsilons=epsilons)

# %%
success
# Out:
# <tf.Tensor: shape=(8, 62), dtype=bool, numpy=
# array([[False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False,  True, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False,  True, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False,  True, False, False],
#        [False, False, False, False, False, False, False,  True,  True,
#         False, False,  True, False, False, False,  True, False,  True,
#          True, False, False, False,  True, False, False, False,  True,
#         False, False, False, False,  True, False, False,  True, False,
#         False, False, False, False,  True,  True,  True, False,  True,
#         False, False, False, False, False,  True,  True,  True, False,
#         False, False, False, False,  True,  True, False, False],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True, False,  True,  True,  True,  True,  True,
#          True,  True, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True]])>

# %% [markdown]
# ## 8. Test last particle

# %%
reload(smc)
# Out:
# <module 'langevin_smc' from '/home/karim-tito/sampling-reliability-measure/karimtito_reliability_meassure/langevin_smc.py'>

# %%
def h_(x):
    u = epsilon*(2*normal_dist.cdf(x)-1)
    u=tf.reshape(u,(x.shape[0],28,28,1)) if len(x.shape)>1 else tf.reshape(u,(1,28,28,1))
    u=tf.clip_by_value(u, clip_value_max=1.0,clip_value_min=0.)
    h = smc.compute_h_tf(model=test_model, input=x_0+u,target_class=y_0)
    return h.numpy()

# %%
gaussian_gen= lambda N: np.random.normal(size=(N,784))

# %%
p_est,s_out= s_t.ImportanceSplittingLp(gen=gaussian_gen,kernel=normal_kernel,h=h_,tau=0,N=2,s=0.1,decay=0.9,T = 20, accept_ratio = 0.9, 
alpha_est = 0.95, alpha_test=0.99,verbose=1, gain_thresh=0.01, check_every=3, p_c = 10**(-20),n_max = int(10**6), 
  reject_forget_rate =0, gain_forget_rate=0, reject_thresh=0.005)
# Out:
# Starting Last Particle algorithm with 116, to certify p<p_c=1e-20, with confidence level alpha =0.010000000000000009.
# Iter =  1  tau_j =  -15.147199  Calls =  2
# Accept ratio:0.85
# Reject rate:0.05000000000000001
# Iter =  4  tau_j =  -14.61069  Calls =  62
# Accept ratio:0.95
# Reject rate:0.07500000000000002
# Iter =  7  tau_j =  -14.415869  Calls =  122
# Accept ratio:0.9
# Reject rate:0.10555555555555557
# Strength of kernel diminished!
# s=0.09000000000000001
# Iter =  10  tau_j =  -14.22985  Calls =  182
# Accept ratio:0.4
# Reject rate:0.13333333333333336
# Strength of kernel diminished!
# s=0.08100000000000002
# Iter =  13  tau_j =  -13.941614  Calls =  242
# Accept ratio:1.0
# Reject rate:0.11000000000000006
# Strength of kernel diminished!
# s=0.05904900000000002
# Iter =  16  tau_j =  -13.762367  Calls =  302
# Accept ratio:1.0
# Reject rate:0.09444444444444448
# Iter =  19  tau_j =  -13.54697  Calls =  362
# Accept ratio:0.75
# Reject rate:0.10000000000000003
# Strength of kernel diminished!
# s=0.043046721000000024
# Iter =  22  tau_j =  -13.432871  Calls =  422
# Accept ratio:0.75
# Reject rate:0.1104166666666667
# Strength of kernel diminished!
# s=0.03138105960900001
# Iter =  25  tau_j =  -13.414767  Calls =  482
# Accept ratio:0.9
# Reject rate:0.10555555555555561
# Strength of kernel diminished!
# s=0.022876792454961013
# Iter =  28  tau_j =  -13.328893  Calls =  542
# Accept ratio:1.0
# Reject rate:0.10833333333333339
# Strength of kernel diminished!
# s=0.01667718169966658
# Iter =  31  tau_j =  -13.2943325  Calls =  602
# Accept ratio:1.0
# Reject rate:0.09848484848484854
# Iter =  34  tau_j =  -13.244304  Calls =  662
# Accept ratio:0.8
# Reject rate:0.10000000000000005
# Strength of kernel diminished!
# s=0.01215766545905694
# Iter =  37  tau_j =  -13.210583  Calls =  722
# Accept ratio:0.75
# Reject rate:0.10769230769230774
# Strength of kernel diminished!
# s=0.00886293811965251
# Iter =  40  tau_j =  -13.196589  Calls =  782
# Accept ratio:1.0
# Reject rate:0.1035714285714286
# Strength of kernel diminished!
# s=0.006461081889226681
# Iter =  43  tau_j =  -13.1755705  Calls =  842
# Accept ratio:1.0
# Reject rate:0.10111111111111114
# Strength of kernel diminished!
# s=0.00471012869724625
# Iter =  46  tau_j =  -13.153334  Calls =  902
# Accept ratio:0.8
# Reject rate:0.10000000000000002
# Strength of kernel diminished!
# s=0.004239115827521626
# Iter =  49  tau_j =  -13.131125  Calls =  962
# Accept ratio:0.95
# Reject rate:0.09901960784313726
# Iter =  52  tau_j =  -13.123701  Calls =  1022
# Accept ratio:1.0
# Reject rate:0.09444444444444446
# Iter =  55  tau_j =  -13.106201  Calls =  1082
# Accept ratio:0.95
# Reject rate:0.09824561403508772
# Iter =  58  tau_j =  -13.100524  Calls =  1142
# Accept ratio:0.85
# Reject rate:0.09666666666666666
# Iter =  61  tau_j =  -13.090469  Calls =  1202
# Accept ratio:0.95
# Reject rate:0.09682539682539683
# Iter =  64  tau_j =  -13.083063  Calls =  1262
# Accept ratio:0.85
# Reject rate:0.09545454545454547
# Iter =  67  tau_j =  -13.070279  Calls =  1322
# Accept ratio:0.85
# Reject rate:0.10289855072463772
# Strength of kernel diminished!
# s=0.002781283894436939
# Iter =  70  tau_j =  -13.06537  Calls =  1382
# Accept ratio:1.0
# Reject rate:0.1041666666666667
# Strength of kernel diminished!
# s=0.0020275559590445286
# Iter =  73  tau_j =  -13.059806  Calls =  1442
# Accept ratio:0.9
# Reject rate:0.10733333333333335
# Strength of kernel diminished!
# s=0.0014780882941434613
# Iter =  76  tau_j =  -13.056133  Calls =  1502
# Accept ratio:1.0
# Reject rate:0.1044871794871795
# Strength of kernel diminished!
# s=0.0010775263664305832
# Iter =  79  tau_j =  -13.051815  Calls =  1562
# Accept ratio:1.0
# Reject rate:0.10308641975308644
# Strength of kernel diminished!
# s=0.0007855167211278952
# Iter =  82  tau_j =  -13.050844  Calls =  1622
# Accept ratio:1.0
# Reject rate:0.10059523809523811
# Strength of kernel diminished!
# s=0.0005726416897022357
# Iter =  85  tau_j =  -13.04888  Calls =  1682
# Accept ratio:0.8
# Reject rate:0.09942528735632186
# Iter =  88  tau_j =  -13.047191  Calls =  1742
# Accept ratio:1.0
# Reject rate:0.09944444444444447
# Iter =  91  tau_j =  -13.046914  Calls =  1802
# Accept ratio:0.7
# Reject rate:0.10430107526881724
# Strength of kernel diminished!
# s=0.00037571021261363684
# Iter =  94  tau_j =  -13.043803  Calls =  1862
# Accept ratio:1.0
# Reject rate:0.1010416666666667
# Strength of kernel diminished!
# s=0.00027389274499534127
# Iter =  97  tau_j =  -13.042369  Calls =  1922
# Accept ratio:1.0
# Reject rate:0.09898989898989903
# Iter =  100  tau_j =  -13.041237  Calls =  1982
# Accept ratio:0.85
# Reject rate:0.09803921568627455
# Iter =  103  tau_j =  -13.040651  Calls =  2042
# Accept ratio:0.9
# Reject rate:0.09809523809523814
# Iter =  106  tau_j =  -13.04027  Calls =  2102
# Accept ratio:1.0
# Reject rate:0.09722222222222227
# Iter =  109  tau_j =  -13.039844  Calls =  2162
# Accept ratio:1.0
# Reject rate:0.09504504504504509
# Iter =  112  tau_j =  -13.039184  Calls =  2222
# Accept ratio:1.0
# Reject rate:0.09385964912280705
# Iter =  115  tau_j =  -13.038492  Calls =  2282
