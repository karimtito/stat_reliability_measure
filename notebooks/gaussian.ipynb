# %%
import pandas as pd
csv_res=pd.read_csv('/home/karim-tito/stat_reliability_measure/logs/gaussian_tests/aggr_res.csv')
p_t=1e-15
select_p_t=csv_res['p_t']==p_t
csv_sel=csv_res[select_p_t]
csv_sel[['method','rho','n_rep','N','T','mean abs error','mean est','min_rate','mean time','K','s','batch_opt','alpha']]
# Out:
#                            method   rho  n_rep    N   T  mean abs error  \
# 3                        amls_pyt   NaN     10   40   1    5.427314e-16
# 4                        amls_pyt   NaN     10  100   1    6.583911e-16
# 5                        amls_pyt   NaN     10  100   1    6.392704e-16
# 6                        amls_pyt   NaN     10  100   1    8.313724e-16
# 18   langevin_base_pyt_unadjusted  10.0     10  100   5    1.000000e-15
# 19   langevin_base_pyt_unadjusted   1.0     10  100   5    7.543597e-16
# 20   langevin_base_pyt_unadjusted   5.0     10  100   5    9.996030e-16
# 21   langevin_base_pyt_unadjusted   2.0     10  100   5    4.696515e-14
# 22   langevin_base_pyt_unadjusted   1.0     10  100   5    7.543597e-16
# 23   langevin_base_pyt_unadjusted   1.0     10  100   5    8.027586e-16
# 24   langevin_base_pyt_unadjusted   1.0     10  100  10    5.970538e-16
# 25   langevin_base_pyt_unadjusted   1.0     10  100  10    7.291980e-16
# ...

# %%
csv_res.sort_values(by=['mean abs error'],ascending=True)[['method','N','mean est','mean abs error']]
# Out:
#                            method     N      mean est  mean abs error
# 3                        amls_pyt    40  4.572686e-16    5.427314e-16
# 24   langevin_base_pyt_unadjusted   100  4.583521e-16    5.970538e-16
# 5                        amls_pyt   100  1.497030e-15    6.392704e-16
# 4                        amls_pyt   100  1.236595e-15    6.583911e-16
# 44  langevin_adapt_pyt_unadjusted    30  3.972715e-16    7.219142e-16
# 25   langevin_base_pyt_unadjusted   100  2.708020e-16    7.291980e-16
# 22   langevin_base_pyt_unadjusted   100  2.838426e-16    7.543597e-16
# 19   langevin_base_pyt_unadjusted   100  2.838426e-16    7.543597e-16
# 48  langevin_adapt_pyt_unadjusted    30  2.854275e-16    7.935954e-16
# 23   langevin_base_pyt_unadjusted   100  1.972414e-16    8.027586e-16
# 39  langevin_adapt_pyt_unadjusted   100  2.864651e-16    8.036684e-16
# 40  langevin_adapt_pyt_unadjusted   100  2.568645e-16    8.085910e-16
# ...
