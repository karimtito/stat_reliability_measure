# %%
import pandas as pd
csv_res=pd.read_csv('/home/karim-tito/stat_reliability_measure/logs/gaussian_tests/aggr_res.csv')
p_t=1e-15
select_p_t=csv_res['p_t']==p_t
csv_sel=csv_res[select_p_t]
csv_sel[['method','rho','n_rep','N','T','mean abs error','mean est','min_rate','mean time','K','s','batch_opt','alpha','g_target']].tail(15)
# Out:
#                            method  rho  n_rep     N    T  mean abs error  \
# 57  langevin_adapt_pyt_unadjusted  NaN     10   100    3    8.343002e-16
# 58  langevin_adapt_pyt_unadjusted  NaN     10    40   10    4.771462e-16
# 59  langevin_adapt_pyt_unadjusted  NaN     10    40    5    7.847891e-16
# 60                       amls_pyt  NaN     10    40   10    6.202083e-16
# 61                       amls_pyt  NaN     10  1000   10    1.853805e-16
# 62                       amls_pyt  NaN     10  1000  100    1.986592e-16
# 63  langevin_adapt_pyt_unadjusted  NaN     10    30    2    1.000000e-15
# 64  langevin_adapt_pyt_unadjusted  NaN     10    30    2    1.000000e-15
# 65  langevin_adapt_pyt_unadjusted  NaN     10    30    2    1.000000e-15
# 66  langevin_adapt_pyt_unadjusted  NaN     10    30    2    9.998513e-16
# 67  langevin_adapt_pyt_unadjusted  NaN     10    30    2    9.999925e-16
# 68  langevin_adapt_pyt_unadjusted  NaN     50    40    5    6.984236e-16
# ...

# %%
csv_res.sort_values(by=['mean abs error'],ascending=True)[['method','rho','n_rep','N','T','mean abs error','mean est','std est','min_rate','mean time','K','s','batch_opt','alpha']].head(15)
# Out:
#                            method  rho  n_rep     N    T  mean abs error  \
# 61                       amls_pyt  NaN     10  1000   10    1.853805e-16
# 62                       amls_pyt  NaN     10  1000  100    1.986592e-16
# 58  langevin_adapt_pyt_unadjusted  NaN     10    40   10    4.771462e-16
# 3                        amls_pyt  NaN     10    40    1    5.427314e-16
# 24   langevin_base_pyt_unadjusted  1.0     10   100   10    5.970538e-16
# 60                       amls_pyt  NaN     10    40   10    6.202083e-16
# 5                        amls_pyt  NaN     10   100    1    6.392704e-16
# 4                        amls_pyt  NaN     10   100    1    6.583911e-16
# 68  langevin_adapt_pyt_unadjusted  NaN     50    40    5    6.984236e-16
# 44  langevin_adapt_pyt_unadjusted  NaN     10    30    5    7.219142e-16
# 25   langevin_base_pyt_unadjusted  1.0     10   100   10    7.291980e-16
# 19   langevin_base_pyt_unadjusted  1.0     10   100    5    7.543597e-16
# ...
